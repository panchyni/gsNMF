# %% [markdown]
# # Git Figures Precusor

# %% [markdown]
# ##### Polished code for figures

# %% [markdown]
# ## Setup Environment

# %%
import numpy as np
import scipy as sp
from scipy import stats
from sklearn.preprocessing import scale
from sklearn.decomposition import NMF
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pickle
import FiguresModule as fm

# %%
import importlib
importlib.reload(fm)
# Out:
# <module 'FiguresModule' from '/home/jupyter-panchy/NMFviaSKLearn/gitFigureV2/FiguresModule.py'>

# %% [markdown]
# ## -------A549 Model-------

# %% [markdown]
# #### Load A549 data and meta data

# %%
# Read files
A549_Egenes_lines = [ln.strip() for ln in open("A549_E_nonnegative_transpose.csv","r").readlines()]
A549_Esamples, A549_Evalues = fm.Process_scRNA_CSV(A549_Egenes_lines)
A549_Mgenes_lines = [ln.strip() for ln in open("A549_M_nonnegative_transpose.csv","r").readlines()]
A549_Msamples, A549_Mvalues = fm.Process_scRNA_CSV(A549_Mgenes_lines)

# Convert values to a numpy array, make non-negative and check shape
array_A549_Evalues = np.array(A549_Evalues) - np.amin(np.array(A549_Evalues))
print(array_A549_Evalues.shape)
array_A549_Mvalues = np.array(A549_Mvalues) - np.amin(np.array(A549_Mvalues))
print(array_A549_Mvalues.shape)
# Out:
# (3568, 179)
# (3568, 114)

# %%
# Prepare Meta-data and get time lables for startified cross-val
A549_meta_lines = [ln.strip() for ln in open("A549_meta.csv").readlines()]

A549_meta_samples = []
A549_Time_labels = []
for ln in A549_meta_lines[1:]:
    split_ln = ln.split(",")
    values = [v.strip("''").strip('""') for v in split_ln]
    A549_meta_samples.append(values[0])
    A549_Time_labels.append(values[8])
    
print(A549_Time_labels[:10])
# Out:
# ['3d', '3d', '3d', '3d', '3d', '7d', '3d', '1d', '7d', '3d']

# %%
# Turn label in to times (in hours)
A549_Reannot_time = fm.Reannotate_Time(A549_Time_labels)
A549_Reannot_colors = fm.Time_to_Color(A549_Time_labels)

# %%
# Get lists for sample for all different time points
time_0d_idxs, time_8h_idxs, time_1d_idxs, time_3d_idxs, time_7d_idxs, time_8h_rm_idxs, time_1d_rm_idxs, time_3d_rm_idxs = fm.Get_Time_Idxs(A549_Time_labels)

# %% [markdown]
# ### A549 model of all data

# %%
W_E_PCC, W_M_PCC = fm.CheckSeedConsistency(array_A549_Evalues,array_A549_Mvalues,tol=1e-6,iter=500)
print("Mean E-dimension Correlation:" + "\t" + str(np.mean(W_E_PCC)))
print("Mean W-dimension Correlation:" + "\t" + str(np.mean(W_M_PCC)))
# Out:
# Mean E-dimension Correlation:	0.9990546398827713
# Mean W-dimension Correlation:	0.9984039907285859

# %%
# Make model on all data
model = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)
A549_Reannot_time = fm.Reannotate_Time(A549_Time_labels)
W_E = model.fit_transform(array_A549_Evalues)
W_M = model.fit_transform(array_A549_Mvalues)

# %%
# Get the non-revertant portion
A549_no_rev_index = []
for i in range(len(A549_Reannot_time)):
        if A549_Reannot_time[i] < 176:
            A549_no_rev_index.append(i)
            
A549_Reannot_time_noRev = [A549_Reannot_time[v] for v in A549_no_rev_index]
W_E_noRev = W_E[A549_no_rev_index,:]
W_M_noRev = W_M[A549_no_rev_index,:]

# %%
# Find Best Features
best_E_Feature_noRev, best_E_corr, best_E_index = fm.GetNegCoefFeature(W_E_noRev,A549_Reannot_time_noRev)
best_M_Feature_noRev, best_M_corr, best_M_index = fm.GetPosCoefFeature(W_M_noRev,A549_Reannot_time_noRev)
print("Best E-score PCC:\t" + "{:.3}".format(best_E_corr) + " ( index =" + str(best_E_index) + ")")
print("Best M-score PCC:\t" + "{:.3}".format(best_M_corr) + " ( index =" + str(best_M_index) + ")")
# Out:
# Best E-score PCC:	-0.562 ( index =0)
# Best M-score PCC:	0.67 ( index =0)

# %%
best_E_Feature = W_E[:,best_E_index]
best_M_Feature = W_M[:,best_M_index]

# %% [markdown]
# ##### All Data Points

# %%
plt.scatter(best_E_Feature,best_M_Feature,s=10,c=A549_Reannot_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %% [markdown]
# ##### EMT Progression Only (no revertant points)

# %%
A549_Reannot_norRev_colors = [A549_Reannot_colors[i] for i in A549_no_rev_index]

# %%
plt.scatter(best_E_Feature[A549_no_rev_index],best_M_Feature[A549_no_rev_index],s=10,c=A549_Reannot_norRev_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
noRev_reg = LinearRegression().fit(np.array([W_E[A549_no_rev_index,0], W_M[A549_no_rev_index,0]]).transpose(), A549_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([W_E[A549_no_rev_index,0], W_M[A549_no_rev_index,0]]).transpose(), A549_Reannot_time_noRev)
print("A549 NMF Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# A549 NMF Model Adjusted R2:	0.484

# %% [markdown]
# ### Seperation of Time Point Samples

# %% [markdown]
# ##### E-scores

# %%
pv08, f08 = fm.ScoreFProb(best_E_Feature,time_0d_idxs,time_8h_idxs)
pv81, f81 = fm.ScoreFProb(best_E_Feature,time_8h_idxs,time_1d_idxs)
pv13, f13 = fm.ScoreFProb(best_E_Feature,time_1d_idxs,time_3d_idxs)
pv37, f37 = fm.ScoreFProb(best_E_Feature,time_3d_idxs,time_7d_idxs)
pv73rm, f73rm = fm.ScoreFProb(best_E_Feature,time_3d_rm_idxs,time_7d_idxs)

print("0 days vs. 8 hours:\t" + "{:.3}".format(f08) + " (" + "{:.3}".format(pv08) + ")" )
print("8 hours vs. 1 day:\t" + "{:.3}".format(f81) + " (" + "{:.3}".format(pv81) + ")" )
print("1 day vs. 3days:\t" + "{:.3}".format(f13) + " (" + "{:.3}".format(pv13) + ")" )
print("3 days vs. 7days:\t" + "{:.3}".format(f37) + " (" + "{:.3}".format(pv37) + ")" )
print("7 days vs. 7+3days_rm:\t" + "{:.3}".format(f73rm) + " (" + "{:.3}".format(pv73rm) + ")" )
# Out:
# 0 days vs. 8 hours:	0.61 (4.45e-13)
# 8 hours vs. 1 day:	0.809 (2.54e-106)
# 1 day vs. 3days:	0.741 (2.12e-60)
# 3 days vs. 7days:	0.567 (0.00764)
# 7 days vs. 7+3days_rm:	0.9 (3.69e-15)

# %% [markdown]
# #### M-scores

# %%
pv08, f08 = fm.ScoreFProb(best_M_Feature,time_8h_idxs,time_0d_idxs)
pv81, f81 = fm.ScoreFProb(best_M_Feature,time_1d_idxs,time_8h_idxs)
pv13, f13 = fm.ScoreFProb(best_M_Feature,time_3d_idxs,time_1d_idxs)
pv37, f37 = fm.ScoreFProb(best_M_Feature,time_7d_idxs,time_3d_idxs)
pv73rm, f73rm = fm.ScoreFProb(best_M_Feature,time_7d_idxs,time_3d_rm_idxs)

print("0 days vs. 8 hours:\t" + "{:.3}".format(f08) + " (" + "{:.3}".format(pv08) + ")" )
print("8 hours vs. 1 day:\t" + "{:.3}".format(f81) + " (" + "{:.3}".format(pv81) + ")" )
print("1 day vs. 3days:\t" + "{:.3}".format(f13) + " (" + "{:.3}".format(pv13) + ")" )
print("3 days vs. 7days:\t" + "{:.3}".format(f37) + " (" + "{:.3}".format(pv37) + ")" )
print("7 days vs. 7+3days_rm:\t" + "{:.3}".format(f73rm) + " (" + "{:.3}".format(pv73rm) + ")" )
# Out:
# 0 days vs. 8 hours:	0.727 (2.69e-49)
# 8 hours vs. 1 day:	0.84 (6.46e-128)
# 1 day vs. 3days:	0.782 (6.17e-82)
# 3 days vs. 7days:	0.61 (3.26e-05)
# 7 days vs. 7+3days_rm:	0.907 (1.28e-15)

# %% [markdown]
# ### Plot Other Models

# %% [markdown]
# #### Z-score

# %%
Zscore_Evalues, Zscore_Mvalues, Zscore_Time, Zscore_Colors, Zscore_Labels = fm.ProcessOtherModels("Zscore_PlottingData_5242021.tsv")

# %%
plt.scatter(Zscore_Evalues,Zscore_Mvalues,s=10,c=Zscore_Colors)

# %%
noRev_reg = LinearRegression().fit(np.array([Zscore_Evalues, Zscore_Mvalues]).transpose(), A549_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([Zscore_Evalues, Zscore_Mvalues]).transpose(), A549_Reannot_time_noRev)
print("A549 Z-score model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# A549 Z-score model Adjusted R2:	0.307

# %%
Zscore_time_0d_idxs = Zscore_Labels[0]
Zscore_time_8h_idxs = Zscore_Labels[1]
Zscore_time_1d_idxs = Zscore_Labels[2]
Zscore_time_3d_idxs = Zscore_Labels[3]
Zscore_time_7d_idxs = Zscore_Labels[4]

# %%
z_pv08, z_f08 = fm.ScoreFProb(Zscore_Evalues,Zscore_time_0d_idxs,Zscore_time_8h_idxs)
z_pv81, z_f81 = fm.ScoreFProb(Zscore_Evalues,Zscore_time_8h_idxs,Zscore_time_1d_idxs)
z_pv13, z_f13 = fm.ScoreFProb(Zscore_Evalues,Zscore_time_1d_idxs,Zscore_time_3d_idxs)
z_pv37, z_f37 = fm.ScoreFProb(Zscore_Evalues,Zscore_time_3d_idxs,Zscore_time_7d_idxs)

print("0 days vs. 8 hours:\t" + "{:.3}".format(z_f08) + " (" + "{:.3}".format(z_pv08) + ")" )
print("8 hours vs. 1 day:\t" + "{:.3}".format(z_f81) + " (" + "{:.3}".format(z_pv81) + ")" )
print("1 day vs. 3days:\t" + "{:.3}".format(z_f13) + " (" + "{:.3}".format(z_pv13) + ")" )
print("3 days vs. 7days:\t" + "{:.3}".format(z_f37) + " (" + "{:.3}".format(z_pv37) + ")" )
# Out:
# 0 days vs. 8 hours:	0.553 (0.000331)
# 8 hours vs. 1 day:	0.602 (2.69e-13)
# 1 day vs. 3days:	0.695 (1.81e-40)
# 3 days vs. 7days:	0.554 (0.0259)

# %%
z_pv08, z_f08 = fm.ScoreFProb(Zscore_Mvalues,Zscore_time_8h_idxs,Zscore_time_0d_idxs)
z_pv81, z_f81 = fm.ScoreFProb(Zscore_Mvalues,Zscore_time_1d_idxs,Zscore_time_8h_idxs)
z_pv13, z_f13 = fm.ScoreFProb(Zscore_Mvalues,Zscore_time_3d_idxs,Zscore_time_1d_idxs)
z_pv37, z_f37 = fm.ScoreFProb(Zscore_Mvalues,Zscore_time_7d_idxs,Zscore_time_3d_idxs)

print("0 days vs. 8 hours:\t" + "{:.3}".format(z_f08) + " (" + "{:.3}".format(z_pv08) + ")" )
print("8 hours vs. 1 day:\t" + "{:.3}".format(z_f81) + " (" + "{:.3}".format(z_pv81) + ")" )
print("1 day vs. 3days:\t" + "{:.3}".format(z_f13) + " (" + "{:.3}".format(z_pv13) + ")" )
print("3 days vs. 7days:\t" + "{:.3}".format(z_f37) + " (" + "{:.3}".format(z_pv37) + ")" )
# Out:
# 0 days vs. 8 hours:	0.506 (0.351)
# 8 hours vs. 1 day:	0.739 (3.79e-64)
# 1 day vs. 3days:	0.652 (1.93e-25)
# 3 days vs. 7days:	0.58 (0.00188)

# %% [markdown]
# #### GSVA

# %%
GSVA_Evalues, GSVA_Mvalues, GSVA_Time, GSVA_Colors, GSVA_Labels = fm.ProcessOtherModels("GSVA_PlottingData_5242021.tsv")

# %%
plt.scatter(GSVA_Evalues,GSVA_Mvalues,s=10,c=GSVA_Colors)

# %%
noRev_reg = LinearRegression().fit(np.array([GSVA_Evalues, GSVA_Mvalues]).transpose(), A549_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([GSVA_Evalues, GSVA_Mvalues]).transpose(), A549_Reannot_time_noRev)
print("A549 GSVA Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# A549 GSVA Model Adjusted R2:	0.0829

# %%
GSVA_time_0d_idxs = GSVA_Labels[0]
GSVA_time_8h_idxs = GSVA_Labels[1]
GSVA_time_1d_idxs = GSVA_Labels[2]
GSVA_time_3d_idxs = GSVA_Labels[3]
GSVA_time_7d_idxs = GSVA_Labels[4]

# %%
g_pv08, g_f08 = fm.ScoreFProb(GSVA_Evalues,GSVA_time_0d_idxs,GSVA_time_8h_idxs)
g_pv81, g_f81 = fm.ScoreFProb(GSVA_Evalues,GSVA_time_8h_idxs,GSVA_time_1d_idxs)
g_pv13, g_f13 = fm.ScoreFProb(GSVA_Evalues,GSVA_time_1d_idxs,GSVA_time_3d_idxs)
g_pv37, g_f37 = fm.ScoreFProb(GSVA_Evalues,GSVA_time_3d_idxs,GSVA_time_7d_idxs)

print("0 days vs. 8 hours:\t" + "{:.3}".format(g_f08) + " (" + "{:.3}".format(g_pv08) + ")" )
print("8 hours vs. 1 day:\t" + "{:.3}".format(g_f81) + " (" + "{:.3}".format(g_pv81) + ")" )
print("1 day vs. 3days:\t" + "{:.3}".format(g_f13) + " (" + "{:.3}".format(g_pv13) + ")" )
print("3 days vs. 7days:\t" + "{:.3}".format(g_f37) + " (" + "{:.3}".format(g_pv37) + ")" )
# Out:
# 0 days vs. 8 hours:	0.515 (0.166)
# 8 hours vs. 1 day:	0.616 (8.97e-17)
# 1 day vs. 3days:	0.503 (0.433)
# 3 days vs. 7days:	0.58 (0.00173)

# %%
g_pv08, g_f08 = fm.ScoreFProb(GSVA_Mvalues,GSVA_time_8h_idxs,GSVA_time_0d_idxs)
g_pv81, g_f81 = fm.ScoreFProb(GSVA_Mvalues,GSVA_time_1d_idxs,GSVA_time_8h_idxs)
g_pv13, g_f13 = fm.ScoreFProb(GSVA_Mvalues,GSVA_time_3d_idxs,GSVA_time_1d_idxs)
g_pv37, g_f37 = fm.ScoreFProb(GSVA_Mvalues,GSVA_time_7d_idxs,GSVA_time_3d_idxs)

print("0 days vs. 8 hours:\t" + "{:.3}".format(g_f08) + " (" + "{:.3}".format(g_pv08) + ")" )
print("8 hours vs. 1 day:\t" + "{:.3}".format(g_f81) + " (" + "{:.3}".format(g_pv81) + ")" )
print("1 day vs. 3days:\t" + "{:.3}".format(g_f13) + " (" + "{:.3}".format(g_pv13) + ")" )
print("3 days vs. 7days:\t" + "{:.3}".format(g_f37) + " (" + "{:.3}".format(g_pv37) + ")" )
# Out:
# 0 days vs. 8 hours:	0.507 (0.327)
# 8 hours vs. 1 day:	0.7 (9e-46)
# 1 day vs. 3days:	0.547 (0.000694)
# 3 days vs. 7days:	0.474 (0.83)

# %% [markdown]
# #### Non-negative PCA

# %%
nnPCA_Evalues, nnPCA_Mvalues, nnPCA_Time, nnPCA_Colors, nnPCA_Labels = fm.ProcessOtherModels("nnPCA_PlottingData_5292021.tsv")

# %%
plt.scatter(nnPCA_Evalues,nnPCA_Mvalues,s=10,c=nnPCA_Colors)

# %%
noRev_reg = LinearRegression().fit(np.array([nnPCA_Evalues, nnPCA_Mvalues]).transpose(), A549_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([nnPCA_Evalues, nnPCA_Mvalues]).transpose(), A549_Reannot_time_noRev)
print("A549 nnPCA Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# A549 nnPCA Adjusted R2:	0.461

# %%
nnPCA_time_0d_idxs = nnPCA_Labels[0]
nnPCA_time_8h_idxs = nnPCA_Labels[1]
nnPCA_time_1d_idxs = nnPCA_Labels[2]
nnPCA_time_3d_idxs = nnPCA_Labels[3]
nnPCA_time_7d_idxs = nnPCA_Labels[4]

# %%
n_pv08, n_f08 = fm.ScoreFProb(nnPCA_Evalues,nnPCA_time_0d_idxs,nnPCA_time_8h_idxs)
n_pv81, n_f81 = fm.ScoreFProb(nnPCA_Evalues,nnPCA_time_8h_idxs,nnPCA_time_1d_idxs)
n_pv13, n_f13 = fm.ScoreFProb(nnPCA_Evalues,nnPCA_time_1d_idxs,nnPCA_time_3d_idxs)
n_pv37, n_f37 = fm.ScoreFProb(nnPCA_Evalues,nnPCA_time_3d_idxs,nnPCA_time_7d_idxs)

print("0 days vs. 8 hours:\t" + "{:.3}".format(n_f08) + " (" + "{:.3}".format(n_pv08) + ")" )
print("8 hours vs. 1 day:\t" + "{:.3}".format(n_f81) + " (" + "{:.3}".format(n_pv81) + ")" )
print("1 day vs. 3days:\t" + "{:.3}".format(n_f13) + " (" + "{:.3}".format(n_pv13) + ")" )
print("3 days vs. 7days:\t" + "{:.3}".format(n_f37) + " (" + "{:.3}".format(n_pv37) + ")" )
# Out:
# 0 days vs. 8 hours:	0.572 (1.55e-06)
# 8 hours vs. 1 day:	0.74 (4.31e-65)
# 1 day vs. 3days:	0.753 (1.71e-66)
# 3 days vs. 7days:	0.578 (0.00229)

# %%
n_pv08, n_f08 = fm.ScoreFProb(nnPCA_Mvalues,nnPCA_time_8h_idxs,nnPCA_time_0d_idxs)
n_pv81, n_f81 = fm.ScoreFProb(nnPCA_Mvalues,nnPCA_time_1d_idxs,nnPCA_time_8h_idxs)
n_pv13, n_f13 = fm.ScoreFProb(nnPCA_Mvalues,nnPCA_time_3d_idxs,nnPCA_time_1d_idxs)
n_pv37, n_f37 = fm.ScoreFProb(nnPCA_Mvalues,nnPCA_time_7d_idxs,nnPCA_time_3d_idxs)

print("0 days vs. 8 hours:\t" + "{:.3}".format(n_f08) + " (" + "{:.3}".format(n_pv08) + ")" )
print("8 hours vs. 1 day:\t" + "{:.3}".format(n_f81) + " (" + "{:.3}".format(n_pv81) + ")" )
print("1 day vs. 3days:\t" + "{:.3}".format(n_f13) + " (" + "{:.3}".format(n_pv13) + ")" )
print("3 days vs. 7days:\t" + "{:.3}".format(n_f37) + " (" + "{:.3}".format(n_pv37) + ")" )
# Out:
# 0 days vs. 8 hours:	0.636 (7.65e-19)
# 8 hours vs. 1 day:	0.834 (6.44e-124)
# 1 day vs. 3days:	0.754 (2.56e-67)
# 3 days vs. 7days:	0.584 (0.00121)

# %% [markdown]
# ### Infer Missing Time Points

# %% [markdown]
# #### -Drop 1st day-

# %%
Drop_1day_indexes = [i for i in range(len(A549_Time_labels)) if i not in time_1d_idxs]

# %%
array_A549_Evalues_drop1day = [array_A549_Evalues[i] for i in Drop_1day_indexes]
array_A549_Mvalues_drop1day = [array_A549_Mvalues[i] for i in Drop_1day_indexes]
array_A549_Evalues_1day = [array_A549_Evalues[i] for i in time_1d_idxs]
array_A549_Mvalues_1day = [array_A549_Mvalues[i] for i in time_1d_idxs]
Time_labels_drop1day = [A549_Time_labels[i] for i in Drop_1day_indexes]

# %%
# Time indexes for Drop 1st day
time_0d_drop1_idxs, time_8h_drop1_idxs, time_1d_drop1_idxs, time_3d_drop1_idxs, time_7d_drop1_idxs, time_8h_rm_drop1_idxs, time_1d_rm_drop1_idxs, time_3d_rm_drop1_idxs = fm.Get_Time_Idxs(Time_labels_drop1day)

# %%
model = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)
Reannot_time_drop1day = fm.Reannotate_Time(Time_labels_drop1day)
W_E_drop1 = model.fit_transform(array_A549_Evalues_drop1day)
W_E_1day = model.transform(array_A549_Evalues_1day)
W_M_drop1 = model.fit_transform(array_A549_Mvalues_drop1day)
W_M_1day = model.transform(array_A549_Mvalues_1day)

# %%
# Get the non-revertant portion
no_rev_index = []
for i in range(len(Reannot_time_drop1day)):
        if Reannot_time_drop1day[i] < 176:
            no_rev_index.append(i)
            
Reannot_time_drop1day_noRev = [Reannot_time_drop1day[v] for v in no_rev_index]
W_E_drop1_noRev = W_E_drop1[no_rev_index,:]
W_M_drop1_noRev = W_M_drop1[no_rev_index,:]

# %%
best_E_Feature_drop1_noRev, best_E_corr_drop1_noRev, best_E_index_drop1_noRev = fm.GetNegCoefFeature(W_E_drop1_noRev,Reannot_time_drop1day_noRev)
best_M_Feature_drop1_noRev, best_M_corr_drop1_noRev, best_M_index_drop1_noRev = fm.GetPosCoefFeature(W_M_drop1_noRev,Reannot_time_drop1day_noRev)
print("Best E-score PCC:\t" + "{:.3}".format(best_E_corr_drop1_noRev) + " ( index =" + str(best_E_index_drop1_noRev) + ")")
print("Best M-score PCC:\t" + "{:.3}".format(best_M_corr_drop1_noRev) + " ( index =" + str(best_M_index_drop1_noRev) + ")")
# Out:
# Best E-score PCC:	-0.645 ( index =0)
# Best M-score PCC:	0.743 ( index =0)

# %%
best_E_Feature_drop1 = W_E_drop1[:,best_E_index_drop1_noRev]
best_M_Feature_drop1 = W_M_drop1[:,best_M_index_drop1_noRev]

# %%
plt.scatter(best_E_Feature_drop1, best_M_Feature_drop1, s=10, c='grey', marker="s", label='first')
plt.scatter(W_E_1day[:,0], W_M_1day[:,0], s=10, c="#DEB887", marker="s", label='first')

# %%
Drop1_Model_Values = []
for i in range(len(best_E_Feature_drop1)):
    line = str(best_E_Feature_drop1[i]) + '\t' + str(best_M_Feature_drop1[i]) + "\n"
    Drop1_Model_Values.append(line)

# %%
output = open("FigureData_A549_NMF_Drop1ModelPoints.tsv","w")
output.write("".join(Drop1_Model_Values))
output.close()

# %%
Drop1_Infer_Values = []
for i in range(len(W_E_1day[:,1])):
    line = str(W_E_1day[i,0]) + '\t' + str(W_M_1day[i,0]) + "\n"
    Drop1_Infer_Values.append(line)

# %%
output = open("FigureData_A549_NMF_Drop1InferPoints.tsv","w")
output.write("".join(Drop1_Infer_Values))
output.close()

# %% [markdown]
# #### Correlation

# %%
Ecorr, Ecorr_pv = sp.stats.pearsonr(W_E_1day[:,0],best_E_Feature[time_1d_idxs])
Mcorr, Mcorr_pv = sp.stats.pearsonr(W_M_1day[:,0],best_M_Feature[time_1d_idxs])

print("Correlation between original 1-day samples and inferred 1-day samples:")
print("E-score correlation: " + "{:.3}".format(Ecorr) + " (" + "{:.3}".format(Ecorr_pv) + ")" )
print("M-score correlation: " + "{:.3}".format(Mcorr) + " (" + "{:.3}".format(Mcorr_pv) + ")" )
# Out:
# Correlation between original 1-day samples and inferred 1-day samples:
# E-score correlation: 0.999 (0.0)
# M-score correlation: 0.999 (0.0)

# %% [markdown]
# #### Seperation

# %% [markdown]
# ##### E-scores

# %%
pv81_drop, f81_drop = fm.ScoreFProb_Drop(best_E_Feature_drop1,time_8h_drop1_idxs,W_E_1day[:,0],'greater')
pv13_drop, f13_drop = fm.ScoreFProb_Drop(best_E_Feature_drop1,time_3d_drop1_idxs,W_E_1day[:,0],'less')

print("8 hours vs 1 day (dropped):\t" + "{:.3}".format(f81_drop) + " (" + "{:.3}".format(pv81_drop) + ")" )
print("1 day (dropped) vs 3 day:\t" + "{:.3}".format(f13_drop) + " (" + "{:.3}".format(pv13_drop) + ")" )
# Out:
# 8 hours vs 1 day (dropped):	0.811 (1.25e-107)
# 1 day (dropped) vs 3 day:	0.752 (5.42e-66)

# %% [markdown]
# ##### M-scores

# %%
pv81_drop, f81_drop = fm.ScoreFProb_Drop(best_M_Feature_drop1,time_8h_drop1_idxs,W_M_1day[:,0],'less')
pv13_drop, f13_drop = fm.ScoreFProb_Drop(best_M_Feature_drop1,time_3d_drop1_idxs,W_M_1day[:,0],'greater')

print("8 hours vs 1 day (dropped):\t" + "{:.3}".format(f81_drop) + " (" + "{:.3}".format(pv81_drop) + ")" )
print("1 day (dropped) vs 3 day:\t" + "{:.3}".format(f13_drop) + " (" + "{:.3}".format(pv13_drop) + ")" )
# Out:
# 8 hours vs 1 day (dropped):	0.842 (2.3e-129)
# 1 day (dropped) vs 3 day:	0.787 (4.54e-85)

# %% [markdown]
# #### -Drop 0-day-

# %%
Drop_0day_indexes = [i for i in range(len(A549_Time_labels)) if i not in time_0d_idxs]

# %%
array_A549_Evalues_drop0day = [array_A549_Evalues[i] for i in Drop_0day_indexes]
array_A549_Mvalues_drop0day = [array_A549_Mvalues[i] for i in Drop_0day_indexes]
array_A549_Evalues_0day = [array_A549_Evalues[i] for i in time_0d_idxs]
array_A549_Mvalues_0day = [array_A549_Mvalues[i] for i in time_0d_idxs]
Time_labels_drop0day = [A549_Time_labels[i] for i in Drop_0day_indexes]

# %% [markdown]
# ##### Time indexes for Drop 0 day

# %%
time_0d_drop0_idxs, time_8h_drop0_idxs, time_1d_drop0_idxs, time_3d_drop0_idxs, time_7d_drop0_idxs, time_8h_rm_drop0_idxs, time_1d_rm_drop0_idxs, time_3d_rm_drop0_idxs = fm.Get_Time_Idxs(Time_labels_drop0day)

# %%
model = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)
Reannot_time_drop0day = fm.Reannotate_Time(Time_labels_drop0day)
W_E_drop0 = model.fit_transform(array_A549_Evalues_drop0day)
W_E_0day = model.transform(array_A549_Evalues_0day)
W_M_drop0 = model.fit_transform(array_A549_Mvalues_drop0day)
W_M_0day = model.transform(array_A549_Mvalues_0day)

# %%
# Get the non-revertant portion
no_rev_index = []
for i in range(len(Reannot_time_drop0day)):
        if Reannot_time_drop0day[i] < 176:
            no_rev_index.append(i)
            
Reannot_time_drop0day_noRev = [Reannot_time_drop0day[v] for v in no_rev_index]
W_E_drop0_noRev = W_E_drop0[no_rev_index,:]
W_M_drop0_noRev = W_M_drop0[no_rev_index,:]

# %%
best_E_Feature_drop0_noRev, best_E_corr_drop0_noRev, best_E_index_drop0_noRev = fm.GetNegCoefFeature(W_E_drop0_noRev,Reannot_time_drop0day_noRev)
best_M_Feature_drop0_noRev, best_M_corr_drop0_noRev, best_M_index_drop0_noRev = fm.GetPosCoefFeature(W_M_drop0_noRev,Reannot_time_drop0day_noRev)
print("Best E-score PCC:\t" + "{:.3}".format(best_E_corr_drop0_noRev) + " ( index =" + str(best_E_index_drop0_noRev) + ")")
print("Best M-score PCC:\t" + "{:.3}".format(best_M_corr_drop0_noRev) + " ( index =" + str(best_M_index_drop0_noRev) + ")")
# Out:
# Best E-score PCC:	-0.518 ( index =0)
# Best M-score PCC:	0.63 ( index =0)

# %%
best_E_Feature_drop0 = W_E_drop0[:,best_E_index_drop0_noRev]
best_M_Feature_drop0 = W_M_drop0[:,best_M_index_drop0_noRev]

# %%
plt.scatter(best_E_Feature_drop0, best_M_Feature_drop0, s=10, c='grey', marker="s", label='first')
plt.scatter(W_E_0day[:,0], W_M_0day[:,0], s=10, c="#1B7837", marker="s", label='first')

# %%
Drop0_Model_Values = []
for i in range(len(best_E_Feature_drop0)):
    line = str(best_E_Feature_drop0[i]) + '\t' + str(best_M_Feature_drop0[i]) + "\n"
    Drop0_Model_Values.append(line)

# %%
output = open("FigureData_A549_NMF_Drop0ModelPoints.tsv","w")
output.write("".join(Drop0_Model_Values))
output.close()

# %%
Drop0_Infer_Values = []
for i in range(len(W_E_0day[:,0])):
    line = str(W_E_0day[i,0]) + '\t' + str(W_M_0day[i,0]) + "\n"
    Drop0_Infer_Values.append(line)

# %%
output = open("FigureData_A549_NMF_Drop0InferPoints.tsv","w")
output.write("".join(Drop0_Infer_Values))
output.close()

# %% [markdown]
# ##### Correlation

# %%
Ecorr, Ecorr_pv = sp.stats.pearsonr(W_E_0day[:,0],best_E_Feature[time_0d_idxs])
Mcorr, Mcorr_pv = sp.stats.pearsonr(W_M_0day[:,0],best_M_Feature[time_0d_idxs])

print("Correlation between origilna 0-day samples and inferred 0-day samples:")
print("E-score correlation:" + "{:.3}".format(Ecorr) + " (" + "{:.3}".format(Ecorr_pv) + ")" )
print("M-score correlation:" + "{:.3}".format(Mcorr) + " (" + "{:.3}".format(Mcorr_pv) + ")" )
# Out:
# Correlation between origilna 0-day samples and inferred 0-day samples:
# E-score correlation:0.981 (0.0)
# M-score correlation:0.976 (0.0)

# %% [markdown]
# #### Seperation

# %% [markdown]
# ##### E-scores

# %%
pv08_drop, f08_drop = fm.ScoreFProb_Drop(best_E_Feature_drop0,time_8h_drop0_idxs,W_E_0day[:,0],'less')

print("0 days (dropped) vs 8 hours:\t" + "{:.3}".format(f08_drop) + " (" + "{:.3}".format(pv08_drop) + ")" )
# Out:
# 0 days (dropped) vs 8 hours:	0.517 (0.134)

# %% [markdown]
# ##### M-scores

# %%
pv08_drop, f08_drop = fm.ScoreFProb_Drop(best_M_Feature_drop0,time_8h_drop0_idxs,W_M_0day[:,0],'greater')

print("0 days (dropped) vs 8 hours:\t" + "{:.3}".format(f08_drop) + " (" + "{:.3}".format(pv08_drop) + ")" )
# Out:
# 0 days (dropped) vs 8 hours:	0.628 (7.11e-17)

# %% [markdown]
# #### -Drop Everything after 3 days-

# %%
Early_indexes = []
Late_indexes = []

Early_indexes.extend(time_0d_idxs)
Early_indexes.extend(time_8h_idxs)
Early_indexes.extend(time_1d_idxs)
Early_indexes.extend(time_3d_idxs)

Late_indexes.extend(time_7d_idxs)
Late_indexes.extend(time_8h_rm_idxs)
Late_indexes.extend(time_1d_rm_idxs)
Late_indexes.extend(time_3d_rm_idxs)

# %%
array_A549_Evalues_early = [array_A549_Evalues[i] for i in Early_indexes]
array_A549_Mvalues_early = [array_A549_Mvalues[i] for i in Early_indexes]
array_A549_Evalues_late = [array_A549_Evalues[i] for i in Late_indexes]
array_A549_Mvalues_late = [array_A549_Mvalues[i] for i in Late_indexes]
array_A549_Evalues_7day = [array_A549_Evalues[i] for i in time_7d_idxs]
array_A549_Mvalues_7day = [array_A549_Mvalues[i] for i in time_7d_idxs]

Time_labels_early = [A549_Time_labels[i] for i in Early_indexes]
Time_labels_late = [A549_Time_labels[i] for i in Late_indexes]
Time_labels_7day = [A549_Time_labels[i] for i in time_7d_idxs]

# %% [markdown]
# ##### Time indexes for our early and late set

# %%
time_0d_early_idxs, time_8h_early_idxs, time_1d_early_idxs, time_3d_early_idxs, time_7d_early_idxs, time_8h_rm_early_idxs, time_1d_rm_early_idxs, time_3d_rm_early_idxs = fm.Get_Time_Idxs(Time_labels_early) 
time_0d_late_idxs, time_8h_late_idxs, time_1d_late_idxs, time_3d_late_idxs, time_7d_late_idxs, time_8h_rm_late_idxs, time_1d_rm_late_idxs, time_3d_rm_late_idxs = fm.Get_Time_Idxs(Time_labels_late)

# %%
model = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)
Reannot_time_early = fm.Reannotate_Time(Time_labels_early)
Reannot_time_late = fm.Reannotate_Time(Time_labels_late)
Reannot_time_7day = fm.Reannotate_Time(Time_labels_7day)
W_E_early = model.fit_transform(array_A549_Evalues_early)
W_E_late = model.transform(array_A549_Evalues_late)
W_E_7day = model.transform(array_A549_Evalues_7day)
W_M_early = model.fit_transform(array_A549_Mvalues_early)
W_M_late = model.transform(array_A549_Mvalues_late)
W_M_7day = model.transform(array_A549_Mvalues_7day)

# %%
# No need to calc reverse here
best_E_Feature_early, best_E_corr_early, best_E_index_early = fm.GetNegCoefFeature(W_E_early,Reannot_time_early)
best_M_Feature_early, best_M_corr_early, best_M_index_early = fm.GetPosCoefFeature(W_M_early,Reannot_time_early)
print("Best E-score PCC:\t" + "{:.3}".format(best_E_corr_early) + " ( index =" + str(best_E_index_early) + ")")
print("Best M-score PCC:\t" + "{:.3}".format(best_M_corr_early) + " ( index =" + str(best_M_index_early) + ")")
# Out:
# Best E-score PCC:	-0.625 ( index =0)
# Best M-score PCC:	0.725 ( index =0)

# %%
plt.scatter(best_E_Feature_early, best_M_Feature_early, s=10, c='grey', marker="s", label='first')
plt.scatter(W_E_7day[:,0], W_M_7day[:,0], s=10, c="#762A83", marker="s", label='first')

# %%
DropLate_Model_Values = []
for i in range(len(best_E_Feature_early)):
    line = str(best_E_Feature_early[i]) + '\t' + str(best_M_Feature_early[i]) + "\n"
    DropLate_Model_Values.append(line)

# %%
output = open("FigureData_A549_NMF_DropLateModelPoints.tsv","w")
output.write("".join(DropLate_Model_Values))
output.close()

# %%
DropLate_Infer_Values = []
for i in range(len(W_E_7day[:,0])):
    line = str(W_E_7day[i,0]) + '\t' + str(W_M_7day[i,0]) + "\n"
    DropLate_Infer_Values.append(line)

# %%
output = open("FigureData_A549_NMF_DropLateInferPoints.tsv","w")
output.write("".join(DropLate_Infer_Values))
output.close()

# %% [markdown]
# #### Correlation

# %%
Ecorr, Ecorr_pv = sp.stats.pearsonr(W_E_7day[:,0],best_E_Feature[time_7d_idxs])
Mcorr, Mcorr_pv = sp.stats.pearsonr(W_M_7day[:,0],best_M_Feature[time_7d_idxs])

print("Correlation between origilna 7-day samples and inferred 7-day samples:")
print("E-score correlation:" + "{:.3}".format(Ecorr) + " (" + "{:.3}".format(Ecorr_pv) + ")" )
print("M-score correlation:" + "{:.3}".format(Mcorr) + " (" + "{:.3}".format(Mcorr_pv) + ")" )
# Out:
# Correlation between origilna 7-day samples and inferred 7-day samples:
# E-score correlation:0.995 (8.18e-127)
# M-score correlation:0.982 (1.02e-93)

# %% [markdown]
# #### Seperation

# %% [markdown]
# ##### E-scores

# %%
pv37_drop, f37_drop = fm.ScoreFProb_Drop(best_E_Feature_early,time_3d_early_idxs,[W_E_late[j,0] for j in time_7d_late_idxs],'greater')
print("3 days vs 7 days (dropped):\t" + "{:.3}".format(f37_drop) + " (" + "{:.3}".format(pv37_drop) + ")" )
# Out:
# 3 days vs 7 days (dropped):	0.528 (0.154)

# %% [markdown]
# ##### M-scores

# %%
pv37_drop, f37_drop = fm.ScoreFProb_Drop(best_M_Feature_early,time_3d_early_idxs,[W_M_late[j,0] for j in time_7d_late_idxs],'less')
print("3 days vs 7 days (dropped):\t" + "{:.3}".format(f37_drop) + " (" + "{:.3}".format(pv37_drop) + ")" )
# Out:
# 3 days vs 7 days (dropped):	0.55 (0.035)

# %% [markdown]
# #### -Drop all Revertant points and infer 3day_removed-

# %%
Normal_indexes = []
Rev_indexes = []

Normal_indexes.extend(time_0d_idxs)
Normal_indexes.extend(time_8h_idxs)
Normal_indexes.extend(time_1d_idxs)
Normal_indexes.extend(time_3d_idxs)
Normal_indexes.extend(time_7d_idxs)

Rev_indexes.extend(time_3d_rm_idxs)

# %%
array_A549_Normal_E = [array_A549_Evalues[i] for i in Normal_indexes]
array_A549_Normal_M = [array_A549_Mvalues[i] for i in Normal_indexes]
array_A549_Rev_E = [array_A549_Evalues[i] for i in Rev_indexes]
array_A549_Rev_M = [array_A549_Mvalues[i] for i in Rev_indexes]

Time_labels_Normal = [A549_Time_labels[i] for i in Normal_indexes]
Time_labels_Rev = [A549_Time_labels[i] for i in Rev_indexes]

# %%
time_0d_norm_idxs, time_8h_norm_idxs, time_1d_norm_idxs, time_3d_norm_idxs, time_7d_norm_idxs, time_8h_rm_norm_idxs, time_1d_rm_norm_idxs, time_3d_rm_norm_idxs = fm.Get_Time_Idxs(Time_labels_Normal) 
time_0d_rev_idxs, time_8h_rev_idxs, time_1d_rev_idxs, time_3d_rev_idxs, time_7d_rev_idxs, time_8h_rm_rev_idxs, time_1d_rm_rev_idxs, time_3d_rm_rev_idxs = fm.Get_Time_Idxs(Time_labels_Rev)

# %%
model = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)
Reannot_time_Norm = fm.Reannotate_Time(Time_labels_Normal)
Reannot_time_Rev = fm.Reannotate_Time(Time_labels_Rev)

W_E_Norm = model.fit_transform(array_A549_Normal_E)
W_E_Rev = model.transform(array_A549_Rev_E)

W_M_Norm = model.fit_transform(array_A549_Normal_M)
W_M_Rev = model.transform(array_A549_Rev_M)

# %%
best_E_Feature_Norm, best_E_corr_Norm, best_E_index_Norm = fm.GetNegCoefFeature(W_E_Norm,Reannot_time_Norm)
best_M_Feature_Norm, best_M_corr_Norm, best_M_index_Norm = fm.GetPosCoefFeature(W_M_Norm,Reannot_time_Norm)
print("Best E-score PCC:\t" + "{:.3}".format(best_E_corr_Norm) + " ( index =" + str(best_E_index_Norm) + ")")
print("Best M-score PCC:\t" + "{:.3}".format(best_M_corr_Norm) + " ( index =" + str(best_M_index_Norm) + ")")
# Out:
# Best E-score PCC:	-0.55 ( index =0)
# Best M-score PCC:	0.655 ( index =0)

# %%
plt.scatter(best_E_Feature_Norm, best_M_Feature_Norm, s=10, c='grey', marker="s", label='first')
plt.scatter(W_E_Rev[:,0], W_M_Rev[:,0], s=10, c="#00008B", marker="s", label='first')

# %%
DropRev_Model_Values = []
for i in range(len(best_E_Feature_Norm)):
    line = str(best_E_Feature_Norm[i]) + '\t' + str(best_M_Feature_Norm[i]) + "\n"
    DropRev_Model_Values.append(line)

# %%
output = open("FigureData_A549_NMF_DropRevModelPoints.tsv","w")
output.write("".join(DropRev_Model_Values))
output.close()

# %%
DropRev_Infer_Values = []
for i in range(len(W_E_Rev[:,0])):
    line = str(W_E_Rev[i,0]) + '\t' + str(W_M_Rev[i,0]) + "\n"
    DropRev_Infer_Values.append(line)

# %%
output = open("FigureData_A549_NMF_DropRevInferPoints.tsv","w")
output.write("".join(DropRev_Infer_Values))
output.close()

# %% [markdown]
# #### Correlation

# %%
Ecorr, Ecorr_pv = sp.stats.pearsonr(W_E_Rev[:,0],best_E_Feature[time_3d_rm_idxs])
Mcorr, Mcorr_pv = sp.stats.pearsonr(W_M_Rev[:,0],best_M_Feature[time_3d_rm_idxs])

print("Correlation between origilna 3-day removed samples and inferred 3-day removed samples:")
print("E-score correlation: " + "{:.3}".format(Ecorr) + " (" + "{:.3}".format(Ecorr_pv) + ")" )
print("M-score correlation: " + "{:.3}".format(Mcorr) + " (" + "{:.3}".format(Mcorr_pv) + ")" )
# Out:
# Correlation between origilna 3-day removed samples and inferred 3-day removed samples:
# E-score correlation: 0.997 (9.29e-46)
# M-score correlation: 0.98 (1.09e-29)

# %% [markdown]
# #### Seperation

# %% [markdown]
# ##### E-scores

# %%
pv73rm_drop, f73rm_drop = fm.ScoreFProb_Drop(best_E_Feature_Norm,time_7d_norm_idxs,W_E_Rev[:,0],'less')
print("7 days vs 3-days removed (dropped):\t" + "{:.3}".format(f73rm_drop) + " (" + "{:.3}".format(pv73rm_drop) + ")" )
# Out:
# 7 days vs 3-days removed (dropped):	0.909 (8.79e-16)

# %% [markdown]
# ##### M-scores

# %%
pv73rm_drop, f73rm_drop = fm.ScoreFProb_Drop(best_M_Feature_Norm,time_7d_norm_idxs,W_M_Rev[:,0],'greater')
print("7 days vs 3-days removed (dropped):\t" + "{:.3}".format(f73rm_drop) + " (" + "{:.3}".format(pv73rm_drop) + ")" )
# Out:
# 7 days vs 3-days removed (dropped):	0.911 (6.38e-16)

# %% [markdown]
# ## -------DU145 Models-------

# %% [markdown]
# ##### DU145 Data

# %%
# Read files
DU145_Egenes_lines = [ln.strip() for ln in open("du145_tgfb1_scale_E_mat_transpose_nnPCAInput_TAN_Mix.csv","r").readlines()]
DU145_Esamples, DU145_Evalues = fm.Process_scRNA_CSV(DU145_Egenes_lines)
DU145_Mgenes_lines = [ln.strip() for ln in open("du145_tgfb1_scale_M_mat_transpose_nnPCAInput_TAN_Mix.csv","r").readlines()]
DU145_Msamples, DU145_Mvalues = fm.Process_scRNA_CSV(DU145_Mgenes_lines)

# Convert values to a numpy array, make non-negative and check shape
array_DU145_Evalues = np.array(DU145_Evalues) - np.amin(np.array(DU145_Evalues))
print(array_DU145_Evalues.shape)
array_DU145_Mvalues = np.array(DU145_Mvalues) - np.amin(np.array(DU145_Mvalues))
print(array_DU145_Mvalues.shape)
# Out:
# (2853, 189)
# (2853, 118)

# %%
# Prepare Meta-data and get time lables for startified cross-val
DU145_meta_lines = [ln.strip() for ln in open("DU145_meta.csv").readlines()]

DU145_Time_labels = []
DU145_meta_samples = []
for ln in DU145_meta_lines[1:]:
    split_ln = ln.split(",")
    values = [v.strip("''").strip('""') for v in split_ln]
    DU145_meta_samples.append(values[0])
    DU145_Time_labels.append(values[8])
    
print(DU145_Time_labels[:10])
# Out:
# ['3d_rm', '7d', '7d', '3d', '3d', '8h_rm', '7d', '1d', '8h_rm', '3d']

# %%
# Turn label in to times (in hours)
DU145_Reannot_time = fm.Reannotate_Time(DU145_Time_labels)
DU145_Reannot_colors = fm.Time_to_Color(DU145_Time_labels)

# %% [markdown]
# #### Check consistency of DU145 Models

# %%
W_E_PCC, W_M_PCC = fm.CheckSeedConsistency(array_DU145_Evalues,array_DU145_Mvalues,tol=1e-6,iter=500)
print("Mean E-dimension Correlation:" + "\t" + str(np.mean(W_E_PCC)))
print("Mean M-dimension Correlation:" + "\t" + str(np.mean(W_M_PCC)))
# Out:
# Mean E-dimension Correlation:	0.8427485518086507
# Mean M-dimension Correlation:	0.9914241741361317

# %%
W_E_PCC, W_M_PCC = fm.CheckSeedConsistency(array_DU145_Evalues,array_DU145_Mvalues,tol=1e-9,iter=2500)
print("Mean E-dimension Correlation:" + "\t" + str(np.mean(W_E_PCC)))
print("Mean M-dimension Correlation:" + "\t" + str(np.mean(W_M_PCC)))
# Out:
# Mean E-dimension Correlation:	0.9981811800812177
# Mean M-dimension Correlation:	0.9980169343119458

# %% [markdown]
# #### DU145 Base Model

# %%
# Base DU145 Model
model_E = NMF(n_components=2, init='random', random_state=1001,tol=1e-9,max_iter=2500)
W_E_train_DU145 = model_E.fit_transform(array_DU145_Evalues)

model_M = NMF(n_components=2, init='random', random_state=1001,tol=1e-9,max_iter=2500)
W_M_train_DU145 = model_E.fit_transform(array_DU145_Mvalues)

DU145_Reannot_time = fm.Reannotate_Time(DU145_Time_labels)

# %%
# Get the non-revertant portion
DU145_no_rev_index = []
for i in range(len(DU145_Reannot_time)):
        if DU145_Reannot_time[i] < 176:
            DU145_no_rev_index.append(i)
            
DU145_Reannot_time_noRev = [DU145_Reannot_time[v] for v in DU145_no_rev_index]
W_E_train_DU145_noRev = W_E_train_DU145[DU145_no_rev_index,:]
W_M_train_DU145_noRev = W_M_train_DU145[DU145_no_rev_index,:]

# %%
# Find Best Features
DU145_best_E_Feature_noRev, DU145_best_E_corr, DU145_best_E_index = fm.GetNegCoefFeature(W_E_train_DU145_noRev,DU145_Reannot_time_noRev)
DU145_best_M_Feature_noRev, DU145_best_M_corr, DU145_best_M_index = fm.GetPosCoefFeature(W_M_train_DU145_noRev,DU145_Reannot_time_noRev)
print("Best E-score PCC:\t" + "{:.3}".format(DU145_best_E_corr) + " ( index =" + str(DU145_best_E_index) + ")")
print("Best M-score PCC:\t" + "{:.3}".format(DU145_best_M_corr) + " ( index =" + str(DU145_best_M_index) + ")")
# Out:
# Best E-score PCC:	-0.318 ( index =0)
# Best M-score PCC:	0.497 ( index =1)

# %%
DU145_Reannot_noRev_colors = [DU145_Reannot_colors[i] for i in DU145_no_rev_index]

# %%
plt.scatter(W_E_train_DU145[DU145_no_rev_index,DU145_best_E_index],W_M_train_DU145[DU145_no_rev_index,DU145_best_M_index],s=10,c=DU145_Reannot_noRev_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
# Ouputdata
DU145_NoRev_lines = []
for i in DU145_no_rev_index:
    line = str(W_E_train_DU145[i,DU145_best_E_index]) + "\t" + str(W_M_train_DU145[i,DU145_best_M_index]) + "\t" + str(DU145_Reannot_time[i]) + "\n"
    DU145_NoRev_lines.append(line)

# %%
output = open("FigureData_DU145_NMF_NoRevPoints.tsv","w")
output.write("".join(DU145_NoRev_lines))
output.close()

# %%
noRev_reg = LinearRegression().fit(np.array([W_E_train_DU145[DU145_no_rev_index,1], W_M_train_DU145[DU145_no_rev_index,1]]).transpose(), DU145_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([W_E_train_DU145[DU145_no_rev_index,1], W_M_train_DU145[DU145_no_rev_index,1]]).transpose(), DU145_Reannot_time_noRev)
print("DU145 Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# DU145 Model Adjusted R2:	0.314

# %% [markdown]
# ### -------A549 by DU145-------

# %% [markdown]
# #### A549 by DU145

# %%
A549_Egenes = [v.strip('"') for v in A549_Egenes_lines[0].split(",")][1:]
A549_Mgenes = [v.strip('"') for v in A549_Mgenes_lines[0].split(",")][1:]

# %%
DU145_Egenes = [v.strip('"') for v in DU145_Egenes_lines[0].split(",")][1:]
DU145_Mgenes = [v.strip('"') for v in DU145_Mgenes_lines[0].split(",")][1:]

# %%
A549_filter_values_E_array, DU145_filter_values_E_array, A549_by_DU145_Egenes = fm.FilterDataByGenes_scRNA(array_A549_Evalues,A549_Egenes,array_DU145_Evalues,DU145_Egenes)

# %%
print("Input Array Dimensions: E-genes")
print(np.shape(A549_filter_values_E_array))
print(np.shape(DU145_filter_values_E_array))
# Out:
# Input Array Dimensions: E-genes
# (3568, 171)
# (2853, 171)

# %%
A549_filter_values_M_array, DU145_filter_values_M_array, A549_by_DU145_Mgenes = fm.FilterDataByGenes_scRNA(array_A549_Mvalues,A549_Mgenes,array_DU145_Mvalues,DU145_Mgenes)

# %%
print("Input Array Dimensions: M-genes")
print(np.shape(A549_filter_values_M_array))
print(np.shape(DU145_filter_values_M_array))
# Out:
# Input Array Dimensions: M-genes
# (3568, 99)
# (2853, 99)

# %% [markdown]
# #### Fit A549 model by DU145 data

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-9,max_iter=2500)

# E data: Train model
DU145_W_E_refit = model_E_refit.fit_transform(DU145_filter_values_E_array)
A549_by_DU145_fit_E = model_E_refit.transform(A549_filter_values_E_array)

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-9,max_iter=2500)

# M data: Train model
DU145_W_M_refit = model_M_refit.fit_transform(DU145_filter_values_M_array)
A549_by_DU145_fit_M = model_M_refit.transform(A549_filter_values_M_array)

# %% [markdown]
# ##### Compare refit to original DU145 model

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(DU145_W_E_refit[:,0],W_E_train_DU145[:,DU145_best_E_index])[0,1]
original_vs_refit1_E = np.corrcoef(DU145_W_E_refit[:,1],W_E_train_DU145[:,DU145_best_E_index])[0,1]
original_vs_refit0_M = np.corrcoef(DU145_W_M_refit[:,0],W_M_train_DU145[:,DU145_best_M_index])[0,1]
original_vs_refit1_M = np.corrcoef(DU145_W_M_refit[:,1],W_M_train_DU145[:,DU145_best_M_index])[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	0.976
# Original vs. 2nd Refit Component:	-0.88
#
# M-dimension
# Original vs. 1st Refit Component:	-0.814
# Original vs. 2nd Refit Component:	0.996

# %%
plt.scatter(A549_by_DU145_fit_E[A549_no_rev_index,0],A549_by_DU145_fit_M[A549_no_rev_index,1],s=10,c=A549_Reannot_norRev_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
# Ouputdata
A549_by_DU145_NoRev_lines = []
for i in A549_no_rev_index:
    line = str(A549_by_DU145_fit_E[i,0]) + "\t" + str(A549_by_DU145_fit_M[i,1]) + "\t" + str(A549_Reannot_time[i]) + "\n"
    A549_by_DU145_NoRev_lines.append(line)

# %%
output = open("FigureData_A549_by_DU14_NMF_NoRevPoints.tsv","w")
output.write("".join(A549_by_DU145_NoRev_lines))
output.close()

# %%
A549_Reannot_time_noRev = [A549_Reannot_time[v] for v in A549_no_rev_index]
noRev_reg = LinearRegression().fit(np.array([A549_by_DU145_fit_E[A549_no_rev_index,0], A549_by_DU145_fit_M[A549_no_rev_index,1]]).transpose(), A549_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([A549_by_DU145_fit_E[A549_no_rev_index,0], A549_by_DU145_fit_M[A549_no_rev_index,1]]).transpose(), A549_Reannot_time_noRev)
print("A549 by DU145 Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# A549 by DU145 Model Adjusted R2:	0.302

# %%
plt.scatter(best_E_Feature[A549_no_rev_index],A549_by_DU145_fit_E[A549_no_rev_index,0],s=10,c=A549_Reannot_norRev_colors)
plt.xlabel("A549 E Score")
plt.ylabel("DU145 E Score")
# Out:
# Text(0, 0.5, 'DU145 E Score')

# %%
# Ouputdata
A549_by_DU145_Escore_lines = []
for i in A549_no_rev_index:
    line = str(best_E_Feature[i]) + "\t" + str(A549_by_DU145_fit_E[i,0]) + "\t" + str(A549_Reannot_time[i]) + "\n"
    A549_by_DU145_Escore_lines.append(line)

# %%
output = open("FigureData_A549_by_DU14_NMF_Escores.tsv","w")
output.write("".join(A549_by_DU145_Escore_lines))
output.close()

# %%
A549E_corr, A549E_pv = sp.stats.pearsonr(best_E_Feature[A549_no_rev_index],A549_by_DU145_fit_E[A549_no_rev_index,0])

print("Correlation of E-scores for A549 data:\t" + "{:.3}".format(A549E_corr) + " (" + "{:.3}".format(A549E_pv) + ")")
# Out:
# Correlation of E-scores for A549 data:	0.459 (2.65e-163)

# %%
plt.scatter(best_M_Feature[A549_no_rev_index],A549_by_DU145_fit_M[A549_no_rev_index,1],s=10,c=A549_Reannot_norRev_colors)
plt.xlabel("A549 M Score")
plt.ylabel("DU145 M Score")
# Out:
# Text(0, 0.5, 'DU145 M Score')

# %%
# Ouputdata
A549_by_DU145_Mscore_lines = []
for i in A549_no_rev_index:
    line = str(best_M_Feature[i]) + "\t" + str(A549_by_DU145_fit_M[i,1]) + "\t" + str(A549_Reannot_time[i]) + "\n"
    A549_by_DU145_Mscore_lines.append(line)

# %%
output = open("FigureData_A549_by_DU14_NMF_Mscores.tsv","w")
output.write("".join(A549_by_DU145_Mscore_lines))
output.close()

# %%
A549M_corr, A549M_pv = sp.stats.pearsonr(best_M_Feature[A549_no_rev_index],A549_by_DU145_fit_M[A549_no_rev_index,1])

print("Correlation of M-scores for A549 data:\t" + "{:.3}".format(A549M_corr) + " (" + "{:.3}".format(A549M_pv) + ")")
# Out:
# Correlation of M-scores for A549 data:	0.841 (0.0)

# %% [markdown]
# #### DU145 by A549

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)
  
# E data: Train model
A549_W_E_refit = model_E_refit.fit_transform(A549_filter_values_E_array)
DU145_by_A549_fit_E = model_E_refit.transform(DU145_filter_values_E_array)

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)

# M data: Train model
A549_W_M_refit = model_M_refit.fit_transform(A549_filter_values_M_array)
DU145_by_A549_fit_M = model_M_refit.transform(DU145_filter_values_M_array)

# %% [markdown]
# ##### Compare to original A549

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(A549_W_E_refit[:,0],best_E_Feature)[0,1]
original_vs_refit1_E = np.corrcoef(A549_W_E_refit[:,1],best_E_Feature)[0,1]
original_vs_refit0_M = np.corrcoef(A549_W_M_refit[:,0],best_M_Feature)[0,1]
original_vs_refit1_M = np.corrcoef(A549_W_M_refit[:,1],best_M_Feature)[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	0.999
# Original vs. 2nd Refit Component:	-0.961
#
# M-dimension
# Original vs. 1st Refit Component:	-0.851
# Original vs. 2nd Refit Component:	0.985

# %%
plt.scatter(DU145_by_A549_fit_E[DU145_no_rev_index,0],DU145_by_A549_fit_M[DU145_no_rev_index,1],s=10,c=DU145_Reannot_noRev_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
# Ouputdata
DU145_by_A549_NoRev_lines = []
for i in DU145_no_rev_index:
    line = str(DU145_by_A549_fit_E[i,0]) + "\t" + str(DU145_by_A549_fit_M[i,1]) + "\t" + str(DU145_Reannot_time[i]) + "\n"
    DU145_by_A549_NoRev_lines.append(line)

# %%
output = open("FigureData_DU145_by_A549_NMF_NoRevPoints.tsv","w")
output.write("".join(DU145_by_A549_NoRev_lines))
output.close()

# %%
DU145_Reannot_time_noRev = [DU145_Reannot_time[v] for v in DU145_no_rev_index]
noRev_reg = LinearRegression().fit(np.array([DU145_by_A549_fit_E[DU145_no_rev_index,0], DU145_by_A549_fit_M[DU145_no_rev_index,1]]).transpose(), DU145_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([DU145_by_A549_fit_E[DU145_no_rev_index,0], DU145_by_A549_fit_M[DU145_no_rev_index,1]]).transpose(), DU145_Reannot_time_noRev)
print("DU145 by A549 Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# DU145 by A549 Model Adjusted R2:	0.246

# %%
plt.scatter(W_E_train_DU145[DU145_no_rev_index,0],DU145_by_A549_fit_E[DU145_no_rev_index,0],s=10,c=DU145_Reannot_noRev_colors)
plt.xlabel("DU145 E Score")
plt.ylabel("A549 E Score")
# Out:
# Text(0, 0.5, 'A549 E Score')

# %%
# Ouputdata
DU145_by_A549_Escore_lines = []
for i in DU145_no_rev_index:
    line = str(W_E_train_DU145[i,0]) + "\t" + str(DU145_by_A549_fit_E[i,0]) + "\t" + str(DU145_Reannot_time[i]) + "\n"
    DU145_by_A549_Escore_lines.append(line)

# %%
output = open("FigureData_DU145_by_A549_NMF_Escore.tsv","w")
output.write("".join(DU145_by_A549_Escore_lines))
output.close()

# %%
DU145E_corr, DU145E_pv = sp.stats.pearsonr(W_E_train_DU145[DU145_no_rev_index,0],DU145_by_A549_fit_E[DU145_no_rev_index,0])
print("Correlation of E-scores for DU145 data:\t" + "{:.3}".format(DU145E_corr) + " (" + "{:.3}".format(DU145E_pv) + ")")
# Out:
# Correlation of E-scores for DU145 data:	0.311 (1.89e-46)

# %%
plt.scatter(W_M_train_DU145[DU145_no_rev_index,1],DU145_by_A549_fit_M[DU145_no_rev_index,1],s=10,c=DU145_Reannot_noRev_colors)
plt.xlabel("DU145 M Score")
plt.ylabel("A549 M Score")
# Out:
# Text(0, 0.5, 'A549 M Score')

# %%
# Ouputdata
DU145_by_A549_Mscore_lines = []
for i in DU145_no_rev_index:
    line = str(W_M_train_DU145[i,1]) + "\t" + str(DU145_by_A549_fit_M[i,1]) + "\t" + str(DU145_Reannot_time[i]) + "\n"
    DU145_by_A549_Mscore_lines.append(line)

# %%
output = open("FigureData_DU145_by_A549_NMF_Mscore.tsv","w")
output.write("".join(DU145_by_A549_Mscore_lines))
output.close()

# %%
DU145M_corr, DU145M_pv = sp.stats.pearsonr(W_M_train_DU145[DU145_no_rev_index,1],DU145_by_A549_fit_M[DU145_no_rev_index,1])
print("Correlation of M-scores for DU145 data:\t" + "{:.3}".format(DU145M_corr) + " (" + "{:.3}".format(DU145M_pv) + ")")
# Out:
# Correlation of M-scores for DU145 data:	0.844 (0.0)

# %% [markdown]
# ## ------- TCGA Data -------

# %% [markdown]
# #### LUAD by A549

# %%
# Load filtered PRAD to reduce file size and memory useage
with open('array_A549_by_LUAD_Evalues_filter.pkl', 'rb') as handle:
    array_A549_by_LUAD_Evalues_filter = pickle.load(handle)
    
with open('LUAD_by_A549_filter_values_E_array.pkl', 'rb') as handle:
    LUAD_by_A549_filter_values_E_array = pickle.load(handle)
    
with open('LUAD_sample_names.pkl', 'rb') as handle:
    LUAD_sample_names = pickle.load(handle)

# %%
print(np.shape(array_A549_by_LUAD_Evalues_filter))
print(np.shape(LUAD_by_A549_filter_values_E_array))
# Out:
# (3568, 178)
# (594, 178)

# %%
# Load filtered PRAD to reduce file size and memory useage
with open('array_A549_by_LUAD_Mvalues_filter.pkl', 'rb') as handle:
    array_A549_by_LUAD_Mvalues_filter = pickle.load(handle)
    
with open('LUAD_by_A549_filter_values_M_array.pkl', 'rb') as handle:
    LUAD_by_A549_filter_values_M_array = pickle.load(handle)

# %%
print(np.shape(array_A549_by_LUAD_Mvalues_filter))
print(np.shape(LUAD_by_A549_filter_values_M_array))
# Out:
# (3568, 111)
# (594, 111)

# %%
# Scale and remove min
LUAD_by_A549_filter_values_E_array_scale = scale(LUAD_by_A549_filter_values_E_array.astype(float),0)
LUAD_by_A549_filter_values_M_array_scale = scale(LUAD_by_A549_filter_values_M_array.astype(float),0)
LUAD_by_A549_filter_values_E_array = LUAD_by_A549_filter_values_E_array_scale - np.amin(LUAD_by_A549_filter_values_E_array_scale)
LUAD_by_A549_filter_values_M_array = LUAD_by_A549_filter_values_M_array_scale - np.amin(LUAD_by_A549_filter_values_M_array_scale)

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)

# E data: Train model
A549_W_E_refit_for_LUAD = model_E_refit.fit_transform(array_A549_by_LUAD_Evalues_filter)
LUAD_by_A549_fit_E = model_E_refit.transform(LUAD_by_A549_filter_values_E_array)

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)

# M data: Train model
A549_W_M_refit_for_LUAD = model_M_refit.fit_transform(array_A549_by_LUAD_Mvalues_filter)
LUAD_by_A549_fit_M = model_M_refit.transform(LUAD_by_A549_filter_values_M_array)

# %% [markdown]
# ##### Check Refit Models

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(A549_W_E_refit_for_LUAD[:,0],best_E_Feature)[0,1]
original_vs_refit1_E = np.corrcoef(A549_W_E_refit_for_LUAD[:,1],best_E_Feature)[0,1]
original_vs_refit0_M = np.corrcoef(A549_W_M_refit_for_LUAD[:,0],best_M_Feature)[0,1]
original_vs_refit1_M = np.corrcoef(A549_W_M_refit_for_LUAD[:,1],best_M_Feature)[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	1.0
# Original vs. 2nd Refit Component:	-0.958
#
# M-dimension
# Original vs. 1st Refit Component:	-0.868
# Original vs. 2nd Refit Component:	0.999

# %% [markdown]
# ###  Process Data --- PRAD

# %% [markdown]
# #### PRAD by DU145

# %%
# Load pre-processed PRAD to reduce file size and memory useage
with open('array_DU145_by_PRAD_Evalues_filter.pkl', 'rb') as handle:
    array_DU145_by_PRAD_Evalues_filter = pickle.load(handle)
    
with open('PRAD_by_DU145_filter_values_E_array.pkl', 'rb') as handle:
    PRAD_by_DU145_filter_values_E_array = pickle.load(handle)

with open('PRAD_sample_names.pkl', 'rb') as handle:
    PRAD_sample_names = pickle.load(handle)

# %%
print(np.shape(array_DU145_by_PRAD_Evalues_filter))
print(np.shape(PRAD_by_DU145_filter_values_E_array))
# Out:
# (2853, 187)
# (551, 187)

# %%
# Load filtered LUAD to reduce file size and memory useage
with open('array_DU145_by_PRAD_Mvalues_filter.pkl', 'rb') as handle:
    array_DU145_by_PRAD_Mvalues_filter = pickle.load(handle)
    
with open('PRAD_by_DU145_filter_values_M_array.pkl', 'rb') as handle:
    PRAD_by_DU145_filter_values_M_array = pickle.load(handle)

# %%
print(np.shape(array_DU145_by_PRAD_Mvalues_filter))
print(np.shape(PRAD_by_DU145_filter_values_M_array))
# Out:
# (2853, 114)
# (551, 114)

# %%
# Scale and remove min
PRAD_by_DU145_filter_values_E_array_scale = scale(PRAD_by_DU145_filter_values_E_array.astype(float),0)
PRAD_by_DU145_filter_values_M_array_scale = scale(PRAD_by_DU145_filter_values_M_array.astype(float),0)
PRAD_by_DU145_filter_values_E_array = PRAD_by_DU145_filter_values_E_array_scale - np.amin(PRAD_by_DU145_filter_values_E_array_scale)
PRAD_by_DU145_filter_values_M_array = PRAD_by_DU145_filter_values_M_array_scale - np.amin(PRAD_by_DU145_filter_values_M_array_scale)

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-9,max_iter=2500)
    
# E data: Train model
DU145_W_E_refit_for_PRAD = model_E_refit.fit_transform(array_DU145_by_PRAD_Evalues_filter)
PRAD_by_DU145_fit_E = model_E_refit.transform(PRAD_by_DU145_filter_values_E_array)

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-9,max_iter=2500)

# M data: Train model
DU145_W_M_refit_for_PRAD = model_M_refit.fit_transform(array_DU145_by_PRAD_Mvalues_filter)
PRAD_by_DU145_fit_M = model_M_refit.transform(PRAD_by_DU145_filter_values_M_array)

# %% [markdown]
# ##### Check Refit Models

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(W_E_train_DU145[:,DU145_best_E_index],DU145_W_E_refit_for_PRAD[:,0])[0,1]
original_vs_refit1_E = np.corrcoef(W_E_train_DU145[:,DU145_best_E_index],DU145_W_E_refit_for_PRAD[:,1])[0,1]
original_vs_refit0_M = np.corrcoef(W_M_train_DU145[:,DU145_best_M_index],DU145_W_M_refit_for_PRAD[:,0])[0,1]
original_vs_refit1_M = np.corrcoef(W_M_train_DU145[:,DU145_best_M_index],DU145_W_M_refit_for_PRAD[:,1])[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	0.999
# Original vs. 2nd Refit Component:	-0.933
#
# M-dimension
# Original vs. 1st Refit Component:	-0.882
# Original vs. 2nd Refit Component:	0.999

# %% [markdown]
# ### LUAD by DU145

# %%
# Load pre-processed PRAD to reduce file size and memory useage
with open('array_DU145_by_LUAD_Evalues_filter.pkl', 'rb') as handle:
    array_DU145_by_LUAD_Evalues_filter = pickle.load(handle)
    
with open('LUAD_by_DU145_filter_values_E_array.pkl', 'rb') as handle:
    LUAD_by_DU145_filter_values_E_array = pickle.load(handle)

# %%
print(np.shape(array_DU145_by_LUAD_Evalues_filter))
print(np.shape(LUAD_by_DU145_filter_values_E_array))
# Out:
# (2853, 187)
# (594, 187)

# %%
# Load pre-filtred LUD to reduce file size and memory useage
with open('array_DU145_by_LUAD_Mvalues_filter.pkl', 'rb') as handle:
    array_DU145_by_LUAD_Mvalues_filter = pickle.load(handle)
    
with open('LUAD_by_DU145_filter_values_M_array.pkl', 'rb') as handle:
    LUAD_by_DU145_filter_values_M_array = pickle.load(handle)

# %%
print(np.shape(array_DU145_by_LUAD_Mvalues_filter))
print(np.shape(LUAD_by_DU145_filter_values_M_array))
# Out:
# (2853, 114)
# (594, 114)

# %%
# Scale and remove min
LUAD_by_DU145_filter_values_E_array_scale = scale(LUAD_by_DU145_filter_values_E_array.astype(float),0)
LUAD_by_DU145_filter_values_M_array_scale = scale(LUAD_by_DU145_filter_values_M_array.astype(float),0)
LUAD_by_DU145_filter_values_E_array = LUAD_by_DU145_filter_values_E_array_scale - np.amin(LUAD_by_DU145_filter_values_E_array_scale)
LUAD_by_DU145_filter_values_M_array = LUAD_by_DU145_filter_values_M_array_scale - np.amin(LUAD_by_DU145_filter_values_M_array_scale)

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-9,max_iter=2500)

# E data: Train model
DU145_W_E_refit_for_LUAD = model_E_refit.fit_transform(array_DU145_by_LUAD_Evalues_filter)
LUAD_by_DU145_fit_E = model_E_refit.transform(LUAD_by_DU145_filter_values_E_array)

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-9,max_iter=2500)

# M data: Train model
DU145_W_M_refit_for_LUAD = model_M_refit.fit_transform(array_DU145_by_LUAD_Mvalues_filter)
LUAD_by_DU145_fit_M = model_M_refit.transform(LUAD_by_DU145_filter_values_M_array)

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(W_E_train_DU145[:,DU145_best_E_index],DU145_W_E_refit_for_LUAD[:,0])[0,1]
original_vs_refit1_E = np.corrcoef(W_E_train_DU145[:,DU145_best_E_index],DU145_W_E_refit_for_LUAD[:,1])[0,1]
original_vs_refit0_M = np.corrcoef(W_M_train_DU145[:,DU145_best_M_index],DU145_W_M_refit_for_LUAD[:,0])[0,1]
original_vs_refit1_M = np.corrcoef(W_M_train_DU145[:,DU145_best_M_index],DU145_W_M_refit_for_LUAD[:,1])[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	0.999
# Original vs. 2nd Refit Component:	-0.933
#
# M-dimension
# Original vs. 1st Refit Component:	-0.882
# Original vs. 2nd Refit Component:	0.999

# %% [markdown]
# ### PRAD by A549

# %%
# Load pre-processed PRAD to reduce file size and memory useage
with open('array_A549_by_PRAD_Evalues_filter.pkl', 'rb') as handle:
    array_A549_by_PRAD_Evalues_filter = pickle.load(handle)
    
with open('PRAD_by_A549_filter_values_E_array.pkl', 'rb') as handle:
    PRAD_by_A549_filter_values_E_array = pickle.load(handle)

# %%
print(np.shape(array_A549_by_PRAD_Evalues_filter))
print(np.shape(PRAD_by_A549_filter_values_E_array))
# Out:
# (3568, 178)
# (551, 178)

# %%
# Load pre-filtered PRAD to reduce file size and memory useage
with open('array_A549_by_PRAD_Mvalues_filter.pkl', 'rb') as handle:
    array_A549_by_PRAD_Mvalues_filter = pickle.load(handle)
    
with open('PRAD_by_A549_filter_values_M_array.pkl', 'rb') as handle:
    PRAD_by_A549_filter_values_M_array = pickle.load(handle)

# %%
# Scale and remove min
PRAD_by_A549_filter_values_E_array_scale = scale(PRAD_by_A549_filter_values_E_array.astype(float),0)
PRAD_by_A549_filter_values_M_array_scale = scale(PRAD_by_A549_filter_values_M_array.astype(float),0)
PRAD_by_A549_filter_values_E_array = PRAD_by_A549_filter_values_E_array_scale - np.amin(PRAD_by_A549_filter_values_E_array_scale)
PRAD_by_A549_filter_values_M_array = PRAD_by_A549_filter_values_M_array_scale - np.amin(PRAD_by_A549_filter_values_M_array_scale)

# %%
print(np.shape(array_A549_by_PRAD_Mvalues_filter))
print(np.shape(PRAD_by_A549_filter_values_M_array))
# Out:
# (3568, 111)
# (551, 111)

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)
 
# E data: Train model
A549_W_E_refit_for_PRAD = model_E_refit.fit_transform(array_A549_by_PRAD_Evalues_filter)
PRAD_by_A549_fit_E = model_E_refit.transform(PRAD_by_A549_filter_values_E_array)

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6,max_iter=500)
 
# M data: Train model
A549_W_M_refit_for_PRAD = model_M_refit.fit_transform(array_A549_by_PRAD_Mvalues_filter)
PRAD_by_A549_fit_M = model_M_refit.transform(PRAD_by_A549_filter_values_M_array)

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(A549_W_E_refit_for_PRAD[:,0],best_E_Feature)[0,1]
original_vs_refit1_E = np.corrcoef(A549_W_E_refit_for_PRAD[:,1],best_E_Feature)[0,1]
original_vs_refit0_M = np.corrcoef(A549_W_M_refit_for_PRAD[:,0],best_M_Feature)[0,1]
original_vs_refit1_M = np.corrcoef(A549_W_M_refit_for_PRAD[:,1],best_M_Feature)[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	1.0
# Original vs. 2nd Refit Component:	-0.958
#
# M-dimension
# Original vs. 1st Refit Component:	-0.868
# Original vs. 2nd Refit Component:	0.999

# %% [markdown]
# ### Compare to Previous Scores

# %% [markdown]
# ##### LUAD Scores

# %%
# Make a dictionary of previous scores
LUAD_previous_values = [ln.strip() for ln in open("LUAD_GSAV.table.sample_names","r")]
LUAD_prev_values_dict = fm.PreviousValues_Lines2Dict(LUAD_previous_values)

# %%
# Align model with previous scores
output = fm.AlignScores (LUAD_sample_names, LUAD_prev_values_dict, LUAD_by_A549_fit_E[:,0], LUAD_by_A549_fit_M[:,1], LUAD_by_DU145_fit_E[:,0], LUAD_by_DU145_fit_M[:,1])

LUAD_by_A549_Escore = output[0]
LUAD_by_A549_Mscore = output[1]
LUAD_by_DU145_Escore = output[2]
LUAD_by_DU145_Mscore = output[3]
LUAD_previous_Escore = output[4]
LUAD_previous_Mscore = output[5]

# %% [markdown]
# ##### Read in GSVA values for PRAD

# %%
# Make a dictionary of previous scores
PRAD_previous_values = [ln.strip() for ln in open("PRAD_Annot_Table.sample_names","r")]
PRAD_prev_values_dict = fm.PreviousValues_Lines2Dict(PRAD_previous_values)

# %%
# Align model with previous scores
output = fm.AlignScores (PRAD_sample_names, PRAD_prev_values_dict, PRAD_by_A549_fit_E[:,0], PRAD_by_A549_fit_M[:,1], PRAD_by_DU145_fit_E[:,0], PRAD_by_DU145_fit_M[:,1])

PRAD_by_A549_Escore = output[0]
PRAD_by_A549_Mscore = output[1]
PRAD_by_DU145_Escore = output[2]
PRAD_by_DU145_Mscore = output[3]
PRAD_previous_Escore = output[4]
PRAD_previous_Mscore = output[5]

# %% [markdown]
# ### Compare Models

# %%
LUAD_by_A549_corr, LUAD_by_A549_pv = sp.stats.pearsonr(LUAD_by_A549_Escore,LUAD_previous_Escore)
print("LUAD Original vs A549 E Scores:\t" + "{:.3}".format(LUAD_by_A549_corr) + " (" + "{:.3}".format(LUAD_by_A549_pv) + ")" )
# Out:
# LUAD Original vs A549 E Scores:	0.719 (3.82e-92)

# %%
LUAD_by_DU145_corr, LUAD_by_DU145_pv = sp.stats.pearsonr(LUAD_by_DU145_Escore,LUAD_previous_Escore)
print("LUAD Original vs E DU145 Scores:\t" + "{:.3}".format(LUAD_by_DU145_corr) + " (" + "{:.3}".format(LUAD_by_DU145_pv) + ")" )
# Out:
# LUAD Original vs E DU145 Scores:	0.715 (5.62e-91)

# %%
LUAD_A549vsDU145_E_corr, LUAD_A549vsDU145_E_pv = sp.stats.pearsonr(LUAD_by_A549_Escore,LUAD_by_DU145_Escore)
print("LUAD A549 vs DU145 M Scores:\t" + "{:.3}".format(LUAD_A549vsDU145_E_corr) + " (" + "{:.3}".format(LUAD_A549vsDU145_E_pv) + ")" )
# Out:
# LUAD A549 vs DU145 M Scores:	0.515 (3.35e-40)

# %%
# spike in color balancing points
LUAD_by_A549_Escore.extend([0,0])
LUAD_by_DU145_Escore.extend([0,0])
LUAD_previous_Escore.extend([-0.714553652765244,0.74104974316114])

sc = plt.scatter(LUAD_by_A549_Escore,LUAD_by_DU145_Escore,c=LUAD_previous_Escore)
plt.xlim([1.4, 2.8])
plt.ylim([0.8, 2.8])
plt.xlabel("A549 E Score")
plt.ylabel("DU145 E Score")
plt.colorbar(sc)
plt.savefig("LUAD_E_AllThreeMeasures.png")
plt.savefig("Figure4_PanelB_LUAD_E_AllThreeMeasures.pdf")

# %%
LUAD_by_A549_corr, LUAD_by_A549_pv = sp.stats.pearsonr(LUAD_by_A549_Mscore,LUAD_previous_Mscore)
print("LUAD Original vs A549 M Scores:\t" + "{:.3}".format(LUAD_by_A549_corr) + " (" + "{:.3}".format(LUAD_by_A549_pv) + ")" )
# Out:
# LUAD Original vs A549 M Scores:	0.623 (7.86e-63)

# %%
LUAD_by_DU145_corr, LUAD_by_DU145_pv = sp.stats.pearsonr(LUAD_by_DU145_Mscore,LUAD_previous_Mscore)
print("LUAD Original vs DU145M Scores:\t" + "{:.3}".format(LUAD_by_DU145_corr) + " (" + "{:.3}".format(LUAD_by_DU145_pv) + ")" )
# Out:
# LUAD Original vs DU145M Scores:	0.646 (6.28e-69)

# %%
LUAD_A549vsDU145_M_corr, LUAD_A549vsDU145_M_pv = sp.stats.pearsonr(LUAD_by_A549_Mscore,LUAD_by_DU145_Mscore)
print("LUAD A549 vs DU145 M Scores:\t" + "{:.3}".format(LUAD_A549vsDU145_M_corr) + " (" + "{:.3}".format(LUAD_A549vsDU145_M_pv) + ")" )
# Out:
# LUAD A549 vs DU145 M Scores:	0.859 (2.56e-168)

# %%
# spike in color balancing points
LUAD_by_A549_Mscore.extend([0,0])
LUAD_by_DU145_Mscore.extend([0,0])
LUAD_previous_Mscore.extend([-0.714553652765244,0.74104974316114])

sc = plt.scatter(LUAD_by_A549_Mscore,LUAD_by_DU145_Mscore,c=LUAD_previous_Mscore)
plt.xlim([0.5, 2.7])
plt.ylim([0.8, 2.3])
plt.xlabel("A549 M Score")
plt.ylabel("DU145 M Score")
plt.colorbar(sc)
plt.savefig("LUAD_M_AllThreeMeasures.png")
plt.savefig("Figure4_PanelD_LUAD_M_AllThreeMeasures.pdf")

# %%
PRAD_by_A549_corr, PRAD_by_A549_pv = sp.stats.pearsonr(PRAD_by_A549_Escore,PRAD_previous_Escore)
print("PRAD Original vs A549 E Scores:\t" + "{:.3}".format(PRAD_by_A549_corr) + " (" + "{:.3}".format(PRAD_by_A549_pv) + ")" )
# Out:
# PRAD Original vs A549 E Scores:	0.489 (2.78e-34)

# %%
PRAD_by_DU145_corr, PRAD_by_DU145_pv = sp.stats.pearsonr(PRAD_by_DU145_Escore,PRAD_previous_Escore)
print("PRAD Original vs DU145 E Scores:\t" + "{:.3}".format(PRAD_by_DU145_corr) + " (" + "{:.3}".format(PRAD_by_DU145_pv) + ")" )
# Out:
# PRAD Original vs DU145 E Scores:	0.723 (1.25e-89)

# %%
PRAD_A549vsDU145_E_corr, PRAD_A549vsDU145_E_pv = sp.stats.pearsonr(PRAD_by_A549_Escore,PRAD_by_DU145_Escore)
print("PRAD A549 vs DU145 E Scores:\t" + "{:.3}".format(PRAD_A549vsDU145_E_corr) + " (" + "{:.3}".format(PRAD_A549vsDU145_E_pv) + ")" )
# Out:
# PRAD A549 vs DU145 E Scores:	0.437 (5.34e-27)

# %%
# spike in color balancing point
PRAD_by_DU145_Escore.extend([0,0])
PRAD_by_A549_Escore.extend([0,0])
PRAD_previous_Escore.extend([-0.714553652765244,0.74104974316114])

sc = plt.scatter(PRAD_by_A549_Escore,PRAD_by_DU145_Escore,c=PRAD_previous_Escore)
plt.xlim([1.8, 3.4])
plt.ylim([1.5, 3.4])
plt.xlabel("A549 E Score")
plt.ylabel("DU145 E Score")
plt.colorbar(sc)
plt.savefig("PRAD_E_AllThreeMeasures.png")
plt.savefig("Figure4_PanelA_PRAD_E_AllThreeMeasures.pdf")

# %%
PRAD_by_A549_corr, PRAD_by_A549_pv = sp.stats.pearsonr(PRAD_by_A549_Mscore,PRAD_previous_Mscore)
print("PRAD Original vs A549 M Scores:\t" + "{:.3}".format(PRAD_by_A549_corr) + " (" + "{:.3}".format(PRAD_by_A549_pv) + ")" )
# Out:
# PRAD Original vs A549 M Scores:	0.849 (1.19e-153)

# %%
PRAD_by_DU145_corr, PRAD_by_DU145_pv = sp.stats.pearsonr(PRAD_by_DU145_Mscore,PRAD_previous_Mscore)
print("PRAD Original vs DU145 M Scores:\t" + "{:.3}".format(PRAD_by_DU145_corr) + " (" + "{:.3}".format(PRAD_by_DU145_pv) + ")" )
# Out:
# PRAD Original vs DU145 M Scores:	0.841 (1.6e-147)

# %%
PRAD_A549vsDU145_M_corr, PRAD_A549vsDU145_M_pv = sp.stats.pearsonr(PRAD_by_A549_Mscore,PRAD_by_DU145_Mscore)
print("PRAD A549 vs DU145 M Scores:\t" + "{:.3}".format(PRAD_A549vsDU145_M_corr) + " (" + "{:.3}".format(PRAD_A549vsDU145_M_pv) + ")" )
# Out:
# PRAD A549 vs DU145 M Scores:	0.896 (1.19e-194)

# %%
# spike in color balancing point
PRAD_by_DU145_Mscore.extend([0,0])
PRAD_by_A549_Mscore.extend([0,0])
PRAD_previous_Mscore.extend([-0.714553652765244,0.74104974316114])

sc = plt.scatter(PRAD_by_A549_Mscore,PRAD_by_DU145_Mscore,c=PRAD_previous_Mscore)
plt.xlim([0.7, 2.3])
plt.ylim([0.5, 2.5])
plt.xlabel("A549 M Score")
plt.ylabel("DU145 M Score")
plt.colorbar(sc)
plt.savefig("PRAD_M_AllThreeMeasures.png")
plt.savefig("Figure4_PanelC_PRAD_M_AllThreeMeasures.pdf")

# %% [markdown]
# ## -------- Mock by TGFB -------

# %% [markdown]
# #### Process Data

# %%
# THIS DATA IS TRANPOSED, NEED TO SWAP SAMPLES AND NAMES AND TRANSPOSE MATRIX
# Read in Mock and TGFB data
# Note: The minimum has not be subtracted from this data, so we will do that when making the models
Mock_Egenes_lines = [ln.strip() for ln in open("Mock_LogTPM_E_unscale_TAN_Seurat.out.csv","r").readlines()]
Mock_Egenes, Mock_Evalues = fm.Process_scRNA_CSV(Mock_Egenes_lines)
Mock_Mgenes_lines = [ln.strip() for ln in open("Mock_LogTPM_M_unscale_TAN_Seurat.out.csv","r").readlines()]
Mock_Mgenes, Mock_Mvalues = fm.Process_scRNA_CSV(Mock_Mgenes_lines)

TGFB1_Egenes_lines = [ln.strip() for ln in open("TGFB1_LogTPM_E_unscale_TAN_Seurat.out.csv","r").readlines()]
TGFB1_Egenes, TGFB1_Evalues = fm.Process_scRNA_CSV(TGFB1_Egenes_lines)
TGFB1_Mgenes_lines = [ln.strip() for ln in open("TGFB1_LogTPM_M_unscale_TAN_Seurat.out.csv","r").readlines()]
TGFB1_Mgenes, TGFB1_Mvalues = fm.Process_scRNA_CSV(TGFB1_Mgenes_lines)

# %%
print(np.array(Mock_Evalues).shape)
print(np.array(Mock_Mvalues).shape)
# Out:
# (191, 5027)
# (98, 5027)

# %%
print(np.array(TGFB1_Evalues).shape)
print(np.array(TGFB1_Mvalues).shape)
# Out:
# (173, 4241)
# (115, 4241)

# %% [markdown]
# ### Tranpose Array ###

# %%
Mock_Evalues = np.transpose(np.array(Mock_Evalues))
Mock_Mvalues = np.transpose(np.array(Mock_Mvalues))
TGFB1_Evalues = np.transpose(np.array(TGFB1_Evalues))
TGFB1_Mvalues = np.transpose(np.array(TGFB1_Mvalues))

# %%
print(np.array(Mock_Evalues).shape)
print(np.array(Mock_Mvalues).shape)
print(np.array(TGFB1_Evalues).shape)
print(np.array(TGFB1_Mvalues).shape)
# Out:
# (5027, 191)
# (5027, 98)
# (4241, 173)
# (4241, 115)

# %% [markdown]
# ### Strip Quotes from Gene Names ###

# %%
Mock_Egenes = [name.strip('"') for name in Mock_Egenes]
Mock_Mgenes = [name.strip('"') for name in Mock_Mgenes]
TGFB1_Egenes = [name.strip('"') for name in TGFB1_Egenes]
TGFB1_Mgenes = [name.strip('"') for name in TGFB1_Mgenes]

# %% [markdown]
# ### Annotation Data ###

# %%
# Read annotation data
Mock_annotation = [ln.strip() for ln in open("Mock_InOut_annot.txt.fixed_name","r")]
TGFB_annotation = [ln.strip() for ln in open("TGFB_InOut_annot.txt.fixed_name","r")]

# %%
# Get positions and colors of inner and outer points
Mock_InOut = [ln.split("\t")[-1] for ln in Mock_annotation]
TGFB_InOut = [ln.split("\t")[-1] for ln in TGFB_annotation]

Mock_Idxs_inner = [i for i in range(len(Mock_InOut)) if Mock_InOut[i] == 'inner']
Mock_Idxs_outer = [i for i in range(len(Mock_InOut)) if Mock_InOut[i] == 'outer']
TGFB_Idxs_inner = [i for i in range(len(TGFB_InOut)) if TGFB_InOut[i] == 'inner']
TGFB_Idxs_outer = [i for i in range(len(TGFB_InOut)) if TGFB_InOut[i] == 'outer']

Mock_colors = fm.Position_to_Color(Mock_InOut)
TGFB_colors = fm.Position_to_Color(TGFB_InOut)

# %%
# Get samples
Mock_InOut_samples = [ln.split("\t")[0].strip('"') for ln in Mock_annotation]
TGFB_InOut_samples = [ln.split("\t")[0].strip('"') for ln in TGFB_annotation]

# %% [markdown]
# ### Mock

# %% [markdown]
# ##### Check Consistency

# %%
W_E_PCC, W_M_PCC = fm.CheckSeedConsistency(Mock_Evalues-np.amin(Mock_Evalues),Mock_Mvalues-np.amin(Mock_Mvalues),tol=1e-6, iter=500)
print("Mean W_E Corr:" + "\t" + str(np.mean(W_E_PCC)))
print("Mean W_M Corr:" + "\t" + str(np.mean(W_M_PCC)))
# Out:
# Mean W_E Corr:	0.9984461212252521
# Mean W_M Corr:	0.9995019707614644

# %% [markdown]
# #### Base Model

# %%
# Make base model
model_E = NMF(n_components=2, init='random', random_state=1001,tol=1e-6, max_iter=500)

# E data: Train model
W_E_train_Mock = model_E.fit_transform(Mock_Evalues-np.amin(Mock_Evalues))
Mock_H_E_train = model_E.components_

# Make base model
model_M = NMF(n_components=2, init='random', random_state=1001,tol=1e-6, max_iter=500)

# M data: Train model
W_M_train_Mock = model_M.fit_transform(Mock_Mvalues-np.amin(Mock_Mvalues))
Mock_H_M_train = model_M.components_

# %%
Mock_BestFeature_E, Mock_pv_E, Mock_f_E, Mock_index_E = fm.Best_EFeature_InOut(W_E_train_Mock,Mock_Idxs_inner,Mock_Idxs_outer)
print("Best E dimension:\t" + "{:.3}".format(Mock_f_E) + " (" + "{:.3}".format(Mock_pv_E) + ", index=" + str(Mock_index_E) + ")")
# Out:
# Best E dimension:	0.61 (6.02e-42, index=0)

# %%
Mock_BestFeature_M, Mock_pv_M, Mock_f_M,  Mock_index_M = fm.Best_MFeature_InOut(W_M_train_Mock,Mock_Idxs_inner,Mock_Idxs_outer)
print("Best M dimension:\t" + "{:.3}".format(Mock_f_M) + " (" + "{:.3}".format(Mock_pv_M) + ", index=" + str(Mock_index_M) + ")")
# Out:
# Best M dimension:	0.728 (2.24e-172, index=0)

# %%
plt.scatter(Mock_BestFeature_E,Mock_BestFeature_M,s=10,c=Mock_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
Mock_Base_outlines = []

for inner_index in Mock_Idxs_inner:
    Mock_Base_outlines.append(str(W_E_train_Mock[inner_index,0]) + "\t" + str(W_M_train_Mock[inner_index,0]) + "\tinner\n")
    
for outer_index in Mock_Idxs_outer:
    Mock_Base_outlines.append(str(W_E_train_Mock[outer_index,0]) + "\t" + str(W_M_train_Mock[outer_index,0]) + "\touter\n")

output = open("MockBaseNMF_ScatterValues.tsv","w")
output.write("".join(Mock_Base_outlines))
output.close()

# %%
# Save H martacies for later comparison
Mock_H_E_dict = {}
Mock_H_M_dict = {}

for E_index in range(len(Mock_Egenes)):
    Mock_H_E_dict[Mock_Egenes[E_index]] = Mock_H_E_train[0,E_index]
    
for M_index in range(len(Mock_Mgenes)):
    Mock_H_M_dict[Mock_Mgenes[M_index]] = Mock_H_M_train[0,M_index]

# %% [markdown]
# ### TGFB

# %% [markdown]
# ##### Check Consistency

# %%
W_E_PCC, W_M_PCC = fm.CheckSeedConsistency(TGFB1_Evalues-np.amin(TGFB1_Evalues),TGFB1_Mvalues-np.amin(TGFB1_Mvalues),tol=1e-6, iter=500)
print("Mean W_E Corr:" + "\t" + str(np.mean(W_E_PCC)))
print("Mean W_M Corr:" + "\t" + str(np.mean(W_M_PCC)))
# Out:
# Mean W_E Corr:	0.9961352518178384
# Mean W_M Corr:	0.7936311523774159

# %% [markdown]
# ##### Increase Convergecne Paramters

# %%
W_E_PCC, W_M_PCC = fm.CheckSeedConsistency(TGFB1_Evalues-np.amin(TGFB1_Evalues),TGFB1_Mvalues-np.amin(TGFB1_Mvalues),tol=1e-9,iter=2500)
print("Mean W_E Corr:" + "\t" + str(np.mean(W_E_PCC)))
print("Mean W_M Corr:" + "\t" + str(np.mean(W_M_PCC)))
# Out:
# Mean W_E Corr:	0.9962709269132023
# Mean W_M Corr:	0.9990836647242811

# %%
# Make base model
model_E_long = NMF(n_components=2, init='random', random_state=1001,tol=1e-9, max_iter=2500)

# E data: Train model
W_E_train_TGFB_long = model_E_long.fit_transform(TGFB1_Evalues-np.amin(TGFB1_Evalues))
TGFB1_H_E_train_long = model_E_long.components_

# Make base model
model_M_long = NMF(n_components=2, init='random', random_state=1001,tol=1e-9, max_iter=2500)
   
# M data: Train model
W_M_train_TGFB_long = model_M_long.fit_transform(TGFB1_Mvalues-np.amin(TGFB1_Mvalues))
TGFB1_H_M_train_long = model_M_long.components_

# %%
TGFB_BestFeature_E, TGFB_pv_E, TGFB_f_E,  TGFB_index_E = fm.Best_EFeature_InOut(W_E_train_TGFB_long,TGFB_Idxs_inner,TGFB_Idxs_outer)
print("Best E dimension:\t" + "{:.3}".format(TGFB_f_E) + " (" + "{:.3}".format(TGFB_pv_E) + ", index=" + str(TGFB_index_E) + ")")
# Out:
# Best E dimension:	0.769 (6.28e-202, index=1)

# %%
TGFB_BestFeature_M, TGFB_pv_M, TGFB_f_M, TGFB_index_M = fm.Best_MFeature_InOut(W_M_train_TGFB_long,TGFB_Idxs_inner,TGFB_Idxs_outer)
print("Best M dimension:\t" + "{:.3}".format(TGFB_f_M) + " (" + "{:.3}".format(TGFB_pv_M) + ", index=" + str(TGFB_index_M) + ")")
# Out:
# Best M dimension:	0.819 (5.82e-284, index=0)

# %%
plt.scatter(W_E_train_TGFB_long[:,1],W_M_train_TGFB_long[:,0],s=10,c=TGFB_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
TGFB_Base_outlines = []

for inner_index in TGFB_Idxs_inner:
    TGFB_Base_outlines.append(str(W_E_train_TGFB_long[inner_index,1]) + "\t" + str(W_M_train_TGFB_long[inner_index,0]) + "\tinner\n")
    
for outer_index in TGFB_Idxs_outer:
    TGFB_Base_outlines.append(str(W_E_train_TGFB_long[outer_index,1]) + "\t" + str(W_M_train_TGFB_long[outer_index,0]) + "\touter\n")

output = open("TGFBBaseNMF_ScatterValues.tsv","w")
output.write("".join(TGFB_Base_outlines))
output.close()

# %%
# Save H matracies for later
TGFB1_H_E_dict = {}
TGFB1_H_M_dict = {}

for E_index in range(len(TGFB1_Egenes)):
    TGFB1_H_E_dict[TGFB1_Egenes[E_index]] = TGFB1_H_E_train_long[1,E_index]
    
for M_index in range(len(TGFB1_Mgenes)):
    TGFB1_H_M_dict[TGFB1_Mgenes[M_index]] = TGFB1_H_M_train_long[0,M_index]

# %% [markdown]
# ### Mock X TGFB1

# %% [markdown]
# #### Filter Data Sets

# %%
Mock_filter_values_E_array, TGFB1_filter_values_E_array, Mock_TGFB1_Egenes = fm.FilterDataByGenes_scRNA(Mock_Evalues,Mock_Egenes,TGFB1_Evalues,TGFB1_Egenes)

# %%
print(np.shape(Mock_filter_values_E_array))
print(np.shape(TGFB1_filter_values_E_array))
# Out:
# (5027, 172)
# (4241, 172)

# %%
Mock_filter_values_M_array, TGFB1_filter_values_M_array, Mock_TGFB1_Mgenes = fm.FilterDataByGenes_scRNA(Mock_Mvalues,Mock_Mgenes,TGFB1_Mvalues,TGFB1_Mgenes)

# %%
print(np.shape(Mock_filter_values_M_array))
print(np.shape(TGFB1_filter_values_M_array))
# Out:
# (5027, 96)
# (4241, 96)

# %% [markdown]
# #### Mock by TGFB

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-9, max_iter=2500)
    
# E data: Train model
TGFB_W_E_refit = model_E_refit.fit_transform(TGFB1_filter_values_E_array-np.amin(TGFB1_filter_values_E_array))
Mock_by_TGFB1_H_E_refit = model_E_refit.components_
Mock_by_TGFB1_fit_E = model_E_refit.transform(Mock_filter_values_E_array-np.amin(Mock_filter_values_E_array))

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-9, max_iter=2500)

# M data: Train model
TGFB_W_M_refit = model_M_refit.fit_transform(TGFB1_filter_values_M_array-np.amin(TGFB1_filter_values_M_array))
Mock_by_TGFB1_H_M_refit = model_M_refit.components_
Mock_by_TGFB1_fit_M = model_M_refit.transform(Mock_filter_values_M_array-np.amin(Mock_filter_values_M_array))

# %% [markdown]
# ##### Check against original

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(W_E_train_TGFB_long[:,1],TGFB_W_E_refit[:,0])[0,1]
original_vs_refit1_E = np.corrcoef(W_E_train_TGFB_long[:,1],TGFB_W_E_refit[:,1])[0,1]
original_vs_refit0_M = np.corrcoef(W_M_train_TGFB_long[:,0],TGFB_W_M_refit[:,0])[0,1]
original_vs_refit1_M = np.corrcoef(W_M_train_TGFB_long[:,0],TGFB_W_M_refit[:,1])[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	1.0
# Original vs. 2nd Refit Component:	-0.946
#
# M-dimension
# Original vs. 1st Refit Component:	-0.906
# Original vs. 2nd Refit Component:	0.995

# %%
plt.scatter(Mock_by_TGFB1_fit_E[:,0],Mock_by_TGFB1_fit_M[:,1],s=10,c=Mock_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
Mock_by_TGFB_outlines = []

for inner_index in Mock_Idxs_inner:
    Mock_by_TGFB_outlines.append(str(Mock_by_TGFB1_fit_E[inner_index,0]) + "\t" + str(Mock_by_TGFB1_fit_M[inner_index,1]) + "\tinner\n")
    
for outer_index in Mock_Idxs_outer:
    Mock_by_TGFB_outlines.append(str(Mock_by_TGFB1_fit_E[outer_index,0]) + "\t" + str(Mock_by_TGFB1_fit_M[outer_index,1]) + "\touter\n")

output = open("MockbyTGFBNMF_ScatterValues.tsv","w")
output.write("".join(Mock_by_TGFB_outlines))
output.close()

# %%
stat, pv = sp.stats.mannwhitneyu(Mock_by_TGFB1_fit_E[Mock_Idxs_inner,0],Mock_by_TGFB1_fit_E[Mock_Idxs_outer,0],alternative='greater')
f_prob = stat/(len(Mock_Idxs_inner)*len(Mock_Idxs_outer))
print("Best E dimension:\t" + "{:.3}".format(f_prob) + " (" + "{:.3}".format(pv) + ")")
# Out:
# Best E dimension:	0.643 (5.54e-69)

# %%
stat, pv = sp.stats.mannwhitneyu(Mock_by_TGFB1_fit_M[Mock_Idxs_outer,1],Mock_by_TGFB1_fit_M[Mock_Idxs_inner,1],alternative='greater')
f_prob = stat/(len(Mock_Idxs_inner)*len(Mock_Idxs_outer))
print("Best M dimension:\t" + "{:.3}".format(f_prob) + " (" + "{:.3}".format(pv) + ")")
# Out:
# Best M dimension:	0.694 (4.7e-126)

# %% [markdown]
# #### TGFB1 by Mock

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6, max_iter=500)
 
# E data: Train model
Mock_W_E_refit = model_E_refit.fit_transform(Mock_filter_values_E_array-np.amin(Mock_filter_values_E_array))
TGFB1_by_Mock_H_E_refit = model_E_refit.components_
TGFB1_by_Mock_fit_E = model_E_refit.transform(TGFB1_filter_values_E_array-np.amin(TGFB1_filter_values_E_array))

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6, max_iter=500)

# M data: Train model
Mock_W_M_refit = model_M_refit.fit_transform(Mock_filter_values_M_array-np.amin(Mock_filter_values_M_array))
TGFB1_by_Mock_H_M_refit = model_M_refit.components_
TGFB1_by_Mock_fit_M = model_M_refit.transform(TGFB1_filter_values_M_array-np.amin(TGFB1_filter_values_M_array))

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(W_E_train_Mock[:,0],Mock_W_E_refit[:,0])[0,1]
original_vs_refit1_E = np.corrcoef(W_E_train_Mock[:,0],Mock_W_E_refit[:,1])[0,1]
original_vs_refit0_M = np.corrcoef(W_M_train_Mock[:,0],Mock_W_M_refit[:,0])[0,1]
original_vs_refit1_M = np.corrcoef(W_M_train_Mock[:,0],Mock_W_M_refit[:,1])[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	0.998
# Original vs. 2nd Refit Component:	-0.949
#
# M-dimension
# Original vs. 1st Refit Component:	-0.912
# Original vs. 2nd Refit Component:	1.0

# %%
plt.scatter(TGFB1_by_Mock_fit_E[:,0],TGFB1_by_Mock_fit_M[:,1],s=10,c=TGFB_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
TGFB_by_Mock_by_outlines = []

for inner_index in TGFB_Idxs_inner:
    TGFB_by_Mock_by_outlines.append(str(TGFB1_by_Mock_fit_E[inner_index,0]) + "\t" + str(TGFB1_by_Mock_fit_M[inner_index,1]) + "\tinner\n")
    
for outer_index in TGFB_Idxs_outer:
    TGFB_by_Mock_by_outlines.append(str(TGFB1_by_Mock_fit_E[outer_index,0]) + "\t" + str(TGFB1_by_Mock_fit_M[outer_index,1]) + "\touter\n")

output = open("TGFBbyMockNMF_ScatterValues.tsv","w")
output.write("".join(TGFB_by_Mock_by_outlines))
output.close()

# %%
stat, pv = sp.stats.mannwhitneyu(TGFB1_by_Mock_fit_E[TGFB_Idxs_inner,0],TGFB1_by_Mock_fit_E[TGFB_Idxs_outer,0],alternative='greater')
f_prob = stat/(len(TGFB_Idxs_inner)*len(TGFB_Idxs_outer))
print("Best E dimension:\t" + "{:.3}".format(f_prob) + " (" + "{:.3}".format(pv) + ")")
# Out:
# Best E dimension:	0.684 (1.9e-96)

# %%
stat, pv = sp.stats.mannwhitneyu(TGFB1_by_Mock_fit_M[TGFB_Idxs_outer,1],TGFB1_by_Mock_fit_M[TGFB_Idxs_inner,1],alternative='greater')
f_prob = stat/(len(TGFB_Idxs_inner)*len(TGFB_Idxs_outer))
print("Best M dimension:\t" + "{:.3}".format(f_prob) + " (" + "{:.3}".format(pv) + ")")
# Out:
# Best M dimension:	0.629 (4.81e-48)

# %% [markdown]
# ### -----A549 X Spatial-----

# %% [markdown]
# #### Mock by A549

# %%
A549_filter_values_E_array, Mock_filter_values_E_array, A549_by_Mock_Egenes = fm.FilterDataByGenes_scRNA(array_A549_Evalues,A549_Egenes,Mock_Evalues,Mock_Egenes)

# %%
print(np.shape(A549_filter_values_E_array))
print(np.shape(Mock_filter_values_E_array))
# Out:
# (3568, 161)
# (5027, 161)

# %%
A549_filter_values_M_array, Mock_filter_values_M_array, A549_by_Mock_Mgenes  = fm.FilterDataByGenes_scRNA(array_A549_Mvalues,A549_Mgenes,Mock_Mvalues,Mock_Mgenes)

# %%
print(np.shape(A549_filter_values_M_array))
print(np.shape(Mock_filter_values_M_array))
# Out:
# (3568, 81)
# (5027, 81)

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6, max_iter=500)

# E data: Train model
A549_W_E_refit_for_Mock = model_E_refit.fit_transform(A549_filter_values_E_array)
Mock_by_A549_H_E_refit = model_E_refit.components_
Mock_by_A549_fit_E = model_E_refit.transform(Mock_filter_values_E_array-np.amin(Mock_filter_values_E_array))

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6, max_iter=500)

# M data: Train model
A549_W_M_refit_for_Mock  = model_M_refit.fit_transform(A549_filter_values_M_array)
Mock_by_A549_H_M_refit = model_M_refit.components_
Mock_by_A549_fit_M = model_M_refit.transform(Mock_filter_values_M_array-np.amin(Mock_filter_values_M_array))

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(best_E_Feature,A549_W_E_refit_for_Mock[:,0])[0,1]
original_vs_refit1_E = np.corrcoef(best_E_Feature,A549_W_E_refit_for_Mock[:,1])[0,1]
original_vs_refit0_M = np.corrcoef(best_M_Feature,A549_W_M_refit_for_Mock[:,0])[0,1]
original_vs_refit1_M = np.corrcoef(best_M_Feature,A549_W_M_refit_for_Mock[:,1])[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	-0.883
# Original vs. 2nd Refit Component:	0.979
#
# M-dimension
# Original vs. 1st Refit Component:	0.984
# Original vs. 2nd Refit Component:	-0.888

# %%
plt.scatter(Mock_by_A549_fit_E[:,1],Mock_by_A549_fit_M[:,0],s=10,c=Mock_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
Mock_by_A549_by_outlines = []

for inner_index in Mock_Idxs_inner:
    Mock_by_A549_by_outlines.append(str(Mock_by_A549_fit_E[inner_index,1]) + "\t" + str(Mock_by_A549_fit_M[inner_index,0]) + "\tinner\n")
    
for outer_index in Mock_Idxs_outer:
    Mock_by_A549_by_outlines.append(str(Mock_by_A549_fit_E[outer_index,1]) + "\t" + str(Mock_by_A549_fit_M[outer_index,0]) + "\touter\n")

output = open("MockByA549NMF_ScatterValues.tsv","w")
output.write("".join(Mock_by_A549_by_outlines))
output.close()

# %%
stat, pv = sp.stats.mannwhitneyu(Mock_by_A549_fit_E[Mock_Idxs_inner,1],Mock_by_A549_fit_E[Mock_Idxs_outer,1])

# Need to manual corret this p-value, because the function likes to flip the sample if we set the alternative to greater
# Using no alternative gives us 1/2 the bi-directional p-value, so 1 - pv is the correct pv for f_prob < 0.5
pv = 1-pv
f_prob = stat/(len(Mock_Idxs_inner)*len(Mock_Idxs_outer))
print("Best E dimension:\t" + "{:.3}".format(f_prob) + " (" + "{:.3}".format(pv) + ")")
# Out:
# Best E dimension:	0.451 (1.0)

# %%
stat, pv = sp.stats.mannwhitneyu(Mock_by_A549_fit_M[Mock_Idxs_outer,0],Mock_by_A549_fit_M[Mock_Idxs_inner,0],alternative='greater')
f_prob = stat/(len(Mock_Idxs_inner)*len(Mock_Idxs_outer))
print("Best M dimension:\t" + "{:.3}".format(f_prob) + " (" + "{:.3}".format(pv) + ")")
# Out:
# Best M dimension:	0.597 (2.65e-33)

# %%
# Save H matracies for later analysis
Mock_by_A549_H_E_dict = {}
Mock_by_A549_H_M_dict = {}


for E_index in range(len(A549_by_Mock_Egenes)):
    Mock_by_A549_H_E_dict[A549_by_Mock_Egenes[E_index]] = Mock_by_A549_H_E_refit[1,E_index]
    
for M_index in range(len(A549_by_Mock_Mgenes)):
    Mock_by_A549_H_M_dict[A549_by_Mock_Mgenes[M_index]] = Mock_by_A549_H_M_refit[0,M_index]

# %% [markdown]
# #### A549 by TGFB

# %%
A549_filter_values_E_array, TGFB1_filter_values_E_array, A549_by_TGFB1_Egenes = fm.FilterDataByGenes_scRNA(array_A549_Evalues,A549_Egenes,TGFB1_Evalues,TGFB1_Egenes)

# %%
print(np.shape(A549_filter_values_E_array))
print(np.shape(TGFB1_filter_values_E_array))
# Out:
# (3568, 150)
# (4241, 150)

# %%
A549_filter_values_M_array, TGFB1_filter_values_M_array, A549_by_TGFB1_Mgenes = fm.FilterDataByGenes_scRNA(array_A549_Mvalues,A549_Mgenes,TGFB1_Mvalues,TGFB1_Mgenes)

# %%
print(np.shape(A549_filter_values_M_array))
print(np.shape(TGFB1_filter_values_M_array))
# Out:
# (3568, 96)
# (4241, 96)

# %%
# Make refit model
model_E_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6, max_iter=500)
  
# E data: Train model
A549_W_E_refit_for_TGFB1 = model_E_refit.fit_transform(A549_filter_values_E_array)
TGFB1_by_A549_H_E_refit = model_E_refit.components_
TGFB1_by_A549_fit_E = model_E_refit.transform(TGFB1_filter_values_E_array-np.amin(TGFB1_filter_values_E_array))

# Make refit model
model_M_refit = NMF(n_components=2, init='random', random_state=1001,tol=1e-6, max_iter=500)
   
# M data: Train model
A549_W_M_refit_for_TGFB1 = model_M_refit.fit_transform(A549_filter_values_M_array)
TGFB1_by_A549_H_M_refit = model_M_refit.components_
TGFB1_by_A549_fit_M = model_M_refit.transform(TGFB1_filter_values_M_array-np.amin(TGFB1_filter_values_M_array))

# %%
# Find the Leading Dimension by comparison to the original model
original_vs_refit0_E = np.corrcoef(best_E_Feature,A549_W_E_refit_for_TGFB1[:,0])[0,1]
original_vs_refit1_E = np.corrcoef(best_E_Feature,A549_W_E_refit_for_TGFB1[:,1])[0,1]
original_vs_refit0_M = np.corrcoef(best_M_Feature,A549_W_M_refit_for_TGFB1[:,0])[0,1]
original_vs_refit1_M = np.corrcoef(best_M_Feature,A549_W_M_refit_for_TGFB1[:,1])[0,1]

print("E-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_E))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_E))
print("")
print("M-dimension")
print("Original vs. 1st Refit Component:\t" + "{:.3}".format(original_vs_refit0_M))
print("Original vs. 2nd Refit Component:\t" + "{:.3}".format(original_vs_refit1_M))
# Out:
# E-dimension
# Original vs. 1st Refit Component:	0.956
# Original vs. 2nd Refit Component:	-0.889
#
# M-dimension
# Original vs. 1st Refit Component:	-0.849
# Original vs. 2nd Refit Component:	0.996

# %%
plt.scatter(TGFB1_by_A549_fit_E[:,0],TGFB1_by_A549_fit_M[:,1],s=10,c=TGFB_colors)
plt.xlabel("E Score")
plt.ylabel("M Score")
# Out:
# Text(0, 0.5, 'M Score')

# %%
TGFB_by_A549_by_outlines = []

for inner_index in TGFB_Idxs_inner:
    TGFB_by_A549_by_outlines.append(str(TGFB1_by_A549_fit_E[inner_index,0]) + "\t" + str(TGFB1_by_A549_fit_M[inner_index,1]) + "\tinner\n")
    
for outer_index in TGFB_Idxs_outer:
    TGFB_by_A549_by_outlines.append(str(TGFB1_by_A549_fit_E[outer_index,0]) + "\t" + str(TGFB1_by_A549_fit_M[outer_index,1]) + "\touter\n")

output = open("TGFBByA549NMF_ScatterValues.tsv","w")
output.write("".join(TGFB_by_A549_by_outlines))
output.close()

# %%
stat, pv = sp.stats.mannwhitneyu(TGFB1_by_A549_fit_E[TGFB_Idxs_inner,0],TGFB1_by_A549_fit_E[TGFB_Idxs_outer,0],alternative='greater')
f_prob = stat/(len(TGFB_Idxs_inner)*len(TGFB_Idxs_outer))
print("Best E dimension:\t" + "{:.3}".format(f_prob) + " (" + "{:.3}".format(pv) + ")")
# Out:
# Best E dimension:	0.585 (3.57e-22)

# %%
stat, pv = sp.stats.mannwhitneyu(TGFB1_by_A549_fit_M[TGFB_Idxs_outer,1],TGFB1_by_A549_fit_M[TGFB_Idxs_inner,1],alternative='greater')
f_prob = stat/(len(TGFB_Idxs_inner)*len(TGFB_Idxs_outer))
print("Best M dimension:\t" + "{:.3}".format(f_prob) + " (" + "{:.3}".format(pv) + ")")
# Out:
# Best M dimension:	0.762 (7.45e-193)

# %%
# Save H matracies for later analysis
TGFB1_by_A549_H_E_dict = {}
TGFB1_by_A549_H_M_dict = {}

for E_index in range(len(A549_by_TGFB1_Egenes)):
    TGFB1_by_A549_H_E_dict[A549_by_TGFB1_Egenes[E_index]] = TGFB1_by_A549_H_E_refit[0,E_index]
    
for M_index in range(len(A549_by_TGFB1_Mgenes)):
    TGFB1_by_A549_H_M_dict[A549_by_TGFB1_Mgenes[M_index]] = TGFB1_by_A549_H_M_refit[1,M_index]

# %% [markdown]
# ### Compare Gene Ranks via H-mats

# %% [markdown]
# #### Mock vs A954

# %%
# Combine H mat dictionaries
Mock_E_combined_dict = fm.MergeDictionaries(Mock_H_E_dict,Mock_by_A549_H_E_dict)
Mock_M_combined_dict = fm.MergeDictionaries(Mock_H_M_dict,Mock_by_A549_H_M_dict)

# %%
# Get Loading values for E dimensions
Mock_by_Mock_Escores = [Mock_E_combined_dict[key]["Base"][0] for key in Mock_E_combined_dict.keys()]
Mock_by_A549_Escores = [Mock_E_combined_dict[key]["A549"][0] for key in Mock_E_combined_dict.keys()]

# %%
plt.scatter(Mock_by_Mock_Escores,Mock_by_A549_Escores)

# %%
Mock_vs_A549_E_corr, Mock_vs_A549_E_pv = sp.stats.pearsonr(Mock_by_Mock_Escores,Mock_by_A549_Escores)
print("E gene loading correlation:\t" + "{:.3}".format(Mock_vs_A549_E_corr) + " (" + "{:.3}".format(Mock_vs_A549_E_pv) + ")")
# Out:
# E gene loading correlation:	-0.0179 (0.821)

# %%
Mock_by_Mock_E = fm.GetGenes(Mock_E_combined_dict,"Base",np.percentile(Mock_by_Mock_Escores,90))
Mock_by_A549_E = fm.GetGenes(Mock_E_combined_dict,"A549",np.percentile(Mock_by_A549_Escores,90))
Mock_Common_E = set(Mock_by_Mock_E).intersection(Mock_by_A549_E)
print("E genes in the 90th percentile of Mock and A549")
Mock_Common_E
# Out:
# E genes in the 90th percentile of Mock and A549
# {'HPGD', 'PERP', 'S100P', 'SLPI'}

# %%
# Get loading values for the M dimension
Mock_by_Mock_Mscores = [Mock_M_combined_dict[key]["Base"][0] for key in Mock_M_combined_dict.keys()]
Mock_by_A549_Mscores = [Mock_M_combined_dict[key]["A549"][0] for key in Mock_M_combined_dict.keys()]

# %%
plt.scatter(Mock_by_Mock_Mscores,Mock_by_A549_Mscores)

# %%
Mock_vs_A549_M_corr, Mock_vs_A549_M_pv = sp.stats.pearsonr(Mock_by_Mock_Mscores,Mock_by_A549_Mscores)
print("M gene loading correlation:\t" + "{:.3}".format(Mock_vs_A549_M_corr) + " (" + "{:.3}".format(Mock_vs_A549_M_pv) + ")")
# Out:
# M gene loading correlation:	0.0635 (0.573)

# %%
Mock_by_Mock_M = fm.GetGenes(Mock_M_combined_dict,"Base",np.percentile(Mock_by_Mock_Mscores,90))
Mock_by_A549_M = fm.GetGenes(Mock_M_combined_dict,"A549",np.percentile(Mock_by_A549_Mscores,90))
Mock_Common_M = set(Mock_by_Mock_M).intersection(Mock_by_A549_M)
print("M genes in the 90th percentile of Mock and A549")
Mock_Common_M
# Out:
# M genes in the 90th percentile of Mock and A549
# {'LGALS1', 'TPM2', 'VIM'}

# %% [markdown]
# #### TGFB vs A549

# %%
# Combine H mat dictionaries
TGFB1_E_combined_dict = fm.MergeDictionaries(TGFB1_H_E_dict,TGFB1_by_A549_H_E_dict)
TGFB1_M_combined_dict = fm.MergeDictionaries(TGFB1_H_M_dict,TGFB1_by_A549_H_M_dict)

# %%
# Get Loading values for E dimensions
TGFB_by_TGFB_Escores = [TGFB1_E_combined_dict[key]["Base"][0] for key in TGFB1_E_combined_dict.keys()]
TGFB_by_A549_Escores = [TGFB1_E_combined_dict[key]["A549"][0] for key in TGFB1_E_combined_dict.keys()]

# %%
plt.scatter(TGFB_by_TGFB_Escores,TGFB_by_A549_Escores)

# %%
TGFB_vs_A549_E_corr, TGFB_vs_A549_E_pv = sp.stats.pearsonr(TGFB_by_TGFB_Escores,TGFB_by_A549_Escores)
print("E gene loading correlation:\t" + "{:.3}".format(TGFB_vs_A549_E_corr) + " (" + "{:.3}".format(TGFB_vs_A549_E_pv) + ")")
# Out:
# E gene loading correlation:	0.0172 (0.834)

# %%
TGFB_by_TGFB_E = fm.GetGenes(TGFB1_E_combined_dict,"Base",np.percentile(TGFB_by_TGFB_Escores,90))
TGFB_by_A549_E = fm.GetGenes(TGFB1_E_combined_dict,"A549",np.percentile(TGFB_by_A549_Escores,90))
TGFB_Common_E = set(TGFB_by_TGFB_E).intersection(TGFB_by_A549_E)
print("E genes in the 90th percentile of Mock and A549")
TGFB_Common_E
# Out:
# E genes in the 90th percentile of Mock and A549
# {'ELF3', 'PERP', 'SLPI'}

# %%
# Get Loading values for M dimensions
TGFB_by_TGFB_Mscores = [TGFB1_M_combined_dict[key]["Base"][0] for key in TGFB1_M_combined_dict.keys()]
TGFB_by_A549_Mscores = [TGFB1_M_combined_dict[key]["A549"][0] for key in TGFB1_M_combined_dict.keys()]

# %%
plt.scatter(TGFB_by_TGFB_Mscores,TGFB_by_A549_Mscores)

# %%
TGFB_vs_A549_M_corr, TGFB_vs_A549_M_pv = sp.stats.pearsonr(TGFB_by_TGFB_Mscores,TGFB_by_A549_Mscores)
print("M gene loading correlation:\t" + "{:.3}".format(TGFB_vs_A549_M_corr) + " (" + "{:.3}".format(TGFB_vs_A549_M_pv) + ")")
# Out:
# M gene loading correlation:	0.477 (8.78e-07)

# %%
TGFB_by_TGFB_M = fm.GetGenes(TGFB1_M_combined_dict,"Base",np.percentile(TGFB_by_TGFB_Mscores,90))
TGFB_by_A549_M = fm.GetGenes(TGFB1_M_combined_dict,"A549",np.percentile(TGFB_by_A549_Mscores,90))
TGFB_Common_M = set(TGFB_by_TGFB_M).intersection(TGFB_by_A549_M)
print("M genes in the 90th percentile of Mock and A549")
TGFB_Common_M
# Out:
# M genes in the 90th percentile of Mock and A549
# {'FN1', 'LGALS1', 'SERPINE1', 'TAGLN', 'TPM2', 'VIM'}

# %% [markdown]
# ##### Mock Down

# %%
print("E genes in 10th percentile of Mock, but the 90th percentile of A549")
Mock_by_Mock_E_Dn = fm.GetGenes_Down(Mock_E_combined_dict,"Base",np.percentile(Mock_by_Mock_Escores,10))
set(Mock_by_Mock_E_Dn).intersection(Mock_by_A549_E)
# Out:
# E genes in 10th percentile of Mock, but the 90th percentile of A549
# {'ABCC3', 'ATP1B1', 'KRT18', 'KRT8', 'NQO1'}

# %%
print("E genes in 90th percentile of Mock, but the 10th percentile of A549")
Mock_by_A549_E_Dn = fm.GetGenes_Down(Mock_E_combined_dict,"A549",np.percentile(Mock_by_A549_Escores,10))
set(Mock_by_A549_E_Dn).intersection(Mock_by_Mock_E)
# Out:
# E genes in 90th percentile of Mock, but the 10th percentile of A549
# {'DSC2', 'FXYD3'}

# %%
print("M genes in 10th percentile of Mock, but the 90th percentile of A549")
Mock_by_Mock_M_Dn = fm.GetGenes_Down(Mock_M_combined_dict,"Base",np.percentile(Mock_by_Mock_Mscores,10))
set(Mock_by_Mock_M_Dn).intersection(Mock_by_A549_M)
# Out:
# M genes in 10th percentile of Mock, but the 90th percentile of A549
# set()

# %%
print("M genes in 90th percentile of Mock, but the 10th percentile of A549")
Mock_by_A549_M_Dn = fm.GetGenes_Down(Mock_M_combined_dict,"A549",np.percentile(Mock_by_A549_Mscores,10))
set(Mock_by_A549_M_Dn).intersection(Mock_by_Mock_M)
# Out:
# M genes in 90th percentile of Mock, but the 10th percentile of A549
# {'CAV1', 'EMP3'}

# %% [markdown]
# #### TGFb Down

# %%
print("E genes in 10th percentile of TGFB1, but the 90th percentile of A549")
TGFB_by_TGFB_E_Dn = fm.GetGenes_Down(TGFB1_E_combined_dict,"Base",np.percentile(TGFB_by_TGFB_Escores,10))
set(TGFB_by_TGFB_E_Dn).intersection(TGFB_by_A549_E)
# Out:
# E genes in 10th percentile of TGFB1, but the 90th percentile of A549
# {'AREG', 'KRT18', 'KRT8', 'NQO1'}

# %%
print("E genes in 90th percentile of TGFB1, but the 10th percentile of A549")
TGFB_by_A549_E_Dn = fm.GetGenes_Down(TGFB1_E_combined_dict,"A549",np.percentile(TGFB_by_A549_Escores,10))
set(TGFB_by_A549_E_Dn).intersection(TGFB_by_TGFB_E)
# Out:
# E genes in 90th percentile of TGFB1, but the 10th percentile of A549
# {'DSC2'}

# %%
print("M genes in 10th percentile of TGFB1, but the 90th percentile of A549")
TGFB_by_TGFB_M_Dn = fm.GetGenes_Down(TGFB1_M_combined_dict,"Base",np.percentile(TGFB_by_TGFB_Mscores,10))
set(TGFB_by_TGFB_M_Dn).intersection(TGFB_by_A549_M)
# Out:
# M genes in 10th percentile of TGFB1, but the 90th percentile of A549
# set()

# %%
print("M genes in 90th percentile of TGFB1, but the 10th percentile of A549")
TGFB_by_A549_M_Dn = fm.GetGenes_Down(TGFB1_M_combined_dict,"A549",np.percentile(TGFB_by_A549_Mscores,10))
set(TGFB_by_A549_M_Dn).intersection(TGFB_by_TGFB_M)
# Out:
# M genes in 90th percentile of TGFB1, but the 10th percentile of A549
# {'EMP3'}

# %% [markdown]
# ### ------- C2 Gene Set Analysis -------

# %%
with open('A549_C2Modules_PC05cutoff.pkl', 'rb') as handle:
    A549_W_dict_PCC05cutoff = pickle.load(handle)

# %% [markdown]
# #### A549 KRAS

# %%
SWEET_KRAS_UP_W = A549_W_dict_PCC05cutoff['SWEET_KRAS_TARGETS_UP'][A549_no_rev_index,:]
best_SWEET_KRAS_UP_Feature_noRev, best_SWEET_KRAS_UP_corr, best_SWEET_KRAS_UP_index = fm.GetPosCoefFeature(SWEET_KRAS_UP_W,A549_Reannot_time_noRev)
print(best_SWEET_KRAS_UP_corr)
# Out:
# 0.6746266923654278

# %%
SWEET_KRAS_DN_W = A549_W_dict_PCC05cutoff['SWEET_KRAS_TARGETS_DN'][A549_no_rev_index,:]
best_SWEET_KRAS_DN_Feature_noRev, best_SWEET_KRAS_DN_corr, best_SWEET_KRAS_DN_index = fm.GetNegCoefFeature(SWEET_KRAS_DN_W,A549_Reannot_time_noRev)
print(best_SWEET_KRAS_DN_corr)
# Out:
# -0.5955201281157149

# %%
noRev_reg = LinearRegression().fit(np.array([best_SWEET_KRAS_DN_Feature_noRev, best_SWEET_KRAS_UP_Feature_noRev]).transpose(), A549_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([best_SWEET_KRAS_DN_Feature_noRev, best_SWEET_KRAS_UP_Feature_noRev]).transpose(), A549_Reannot_time_noRev)
print("A549 KRAS Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# A549 KRAS Model Adjusted R2:	0.48

# %%
plt.scatter(best_SWEET_KRAS_DN_Feature_noRev,best_SWEET_KRAS_UP_Feature_noRev,c=A549_Reannot_norRev_colors)

# %% [markdown]
# #### A549 LMP

# %%
WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_W = A549_W_dict_PCC05cutoff['WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP'][A549_no_rev_index,:]
best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_Feature_noRev, best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_corr, best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_index = fm.GetNegCoefFeature(WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_W,A549_Reannot_time_noRev)
print(best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_corr)
# Out:
# -0.6568504498178411

# %%
WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_W = A549_W_dict_PCC05cutoff['WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN'][A549_no_rev_index,:]
best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_Feature_noRev, best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_corr, best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_index = fm.GetPosCoefFeature(WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_W,A549_Reannot_time_noRev)
print(best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_corr)
# Out:
# 0.6507469066374796

# %%
noRev_reg = LinearRegression().fit(np.array([best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_Feature_noRev, best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_Feature_noRev]).transpose(), A549_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_Feature_noRev, best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_Feature_noRev]).transpose(), A549_Reannot_time_noRev)
print("A549 LMP Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# A549 LMP Model Adjusted R2:	0.491

# %%
plt.scatter(best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_UP_Feature_noRev,best_WAMUNYOKOLI_OVARIAN_CANCER_LMP_DN_Feature_noRev,c=A549_Reannot_norRev_colors)

# %% [markdown]
# #### A549 Metastasis

# %%
RICKMAN_METASTASIS_DN_W = A549_W_dict_PCC05cutoff['RICKMAN_METASTASIS_DN'][A549_no_rev_index,:]
best_RICKMAN_METASTASIS_DN_Feature_noRev, best_RICKMAN_METASTASIS_DN_corr, best_RICKMAN_METASTASIS_DN_index = fm.GetNegCoefFeature(RICKMAN_METASTASIS_DN_W,A549_Reannot_time_noRev)
print(best_RICKMAN_METASTASIS_DN_corr)
# Out:
# -0.6310461831226204

# %%
HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESIS_W = A549_W_dict_PCC05cutoff['HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESIS'][A549_no_rev_index,:]
best_HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESISN_Feature_noRev, best_HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESIS_corr, best_RICKMAN_METASTASIS_DN_index = fm.GetPosCoefFeature(HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESIS_W,A549_Reannot_time_noRev)
print(best_HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESIS_corr)
# Out:
# 0.6605634687946118

# %%
noRev_reg = LinearRegression().fit(np.array([best_RICKMAN_METASTASIS_DN_Feature_noRev, best_HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESISN_Feature_noRev]).transpose(), A549_Reannot_time_noRev)
noRev_reg_R2 = noRev_reg.score(np.array([best_RICKMAN_METASTASIS_DN_Feature_noRev, best_HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESISN_Feature_noRev]).transpose(), A549_Reannot_time_noRev)
print("A549 Metastasis Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# A549 Metastasis Model Adjusted R2:	0.478

# %%
plt.scatter(best_RICKMAN_METASTASIS_DN_Feature_noRev,best_HELLEBREKERS_SILENCED_DURING_TUMOR_ANGIOGENESISN_Feature_noRev,c=A549_Reannot_norRev_colors)

# %% [markdown]
# ### -------Tram Cancer/Drug Module Analysis-------

# %%
# Tram Meta Data
# Prepare Meta-data
annotation_lines = [ln.strip() for ln in open("Tarmetinib_RegressCellLine_Scale_annotation.csv").readlines()]

Tram_Sample_labels = []
Tram_CellLine_labels = []
Tram_Time_labels = []
for ln in annotation_lines[1:]:
    split_ln = ln.split(",")
    values = [v.strip("''").strip('""') for v in split_ln]
    Tram_Sample_labels.append(values[0])
    Tram_CellLine_labels.append(values[1])
    Tram_Time_labels.append(values[2])

# %%
Tram_Time_values = [float(v) for v in Tram_Time_labels]
print(Tram_Time_values[0:10])
# Out:
# [24.0, 24.0, 3.0, 6.0, 6.0, 24.0, 3.0, 3.0, 12.0, 48.0]

# %%
def Tram_Time_to_Color(time_labels):

    Reannot_colors = []
    for v in time_labels:
        if v == '0':
            Reannot_colors.append("#1B7837")
        elif v == '3':
            Reannot_colors.append("#5AAE61")
        elif v == '6':
            Reannot_colors.append("#DEB887")
        elif v == '12':
            Reannot_colors.append("#F39C12")
        elif v == '24':
            Reannot_colors.append("#9970AB")
        elif v == '48':
            Reannot_colors.append("#762A83")

    return Reannot_colors

# %%
Tram_Time_colors = Tram_Time_to_Color(Tram_Time_labels)

# %%
with open('Tram_CancerDrugModules_PC035cutoff.pkl', 'rb') as handle:
    Tram_W_dict_PCC035cutoff = pickle.load(handle)

# %%
KRAS_600_UP_V1_DN_W = Tram_W_dict_PCC035cutoff['KRAS.600_UP.V1_DN']
best_KRAS_600_UP_V1_DN_W_Feature, best_KRAS_600_UP_V1_DN_W_corr, best_KRAS_600_UP_V1_DN_Windex = fm.GetPosCoefFeature(KRAS_600_UP_V1_DN_W,Tram_Time_values)
print(best_KRAS_600_UP_V1_DN_W_corr)
# Out:
# 0.5362419099898872

# %%
KRAS_600_UP_V1_UP_W = Tram_W_dict_PCC035cutoff['KRAS.600_UP.V1_UP']
best_KRAS_600_UP_V1_UP_W_Feature, best_KRAS_600_UP_V1_UP_W_corr, best_KRAS_600_UP_V1_UP_Windex = fm.GetNegCoefFeature(KRAS_600_UP_V1_UP_W,Tram_Time_values)
print(best_KRAS_600_UP_V1_UP_W_corr)
# Out:
# -0.371606860900062

# %%
noRev_reg = LinearRegression().fit(np.array([best_KRAS_600_UP_V1_UP_W_Feature, best_KRAS_600_UP_V1_DN_W_Feature]).transpose(), Tram_Time_values)
noRev_reg_R2 = noRev_reg.score(np.array([best_KRAS_600_UP_V1_UP_W_Feature, best_KRAS_600_UP_V1_DN_W_Feature]).transpose(), Tram_Time_values)
print("Tram KRAS Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# Tram KRAS Model Adjusted R2:	0.354

# %%
plt.scatter(best_KRAS_600_UP_V1_UP_W_Feature,best_KRAS_600_UP_V1_DN_W_Feature,c=Tram_Time_colors)

# %%
LEF1_UP_V1_DN_W = Tram_W_dict_PCC035cutoff['LEF1_UP.V1_DN']
best_LEF1_UP_V1_DN_W_Feature, best_LEF1_UP_V1_DN_W_corr, best_LEF1_UP_V1_DN_W_index = fm.GetPosCoefFeature(LEF1_UP_V1_DN_W,Tram_Time_values)
print(best_LEF1_UP_V1_DN_W_corr)
# Out:
# 0.539692912758369

# %%
LEF1_UP_V1_UP_W = Tram_W_dict_PCC035cutoff['LEF1_UP.V1_UP']
best_LEF1_UP_V1_UP_W_Feature, best_LEF1_UP_V1_UP_W_corr, best_LEF1_UP_V1_UP_W_index = fm.GetNegCoefFeature(LEF1_UP_V1_UP_W,Tram_Time_values)
print(best_LEF1_UP_V1_UP_W_corr)
# Out:
# -0.4129996814781924

# %%
noRev_reg = LinearRegression().fit(np.array([best_LEF1_UP_V1_UP_W_Feature, best_LEF1_UP_V1_DN_W_Feature]).transpose(), Tram_Time_values)
noRev_reg_R2 = noRev_reg.score(np.array([best_LEF1_UP_V1_UP_W_Feature, best_LEF1_UP_V1_DN_W_Feature]).transpose(), Tram_Time_values)
print("Tram LEF Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# Tram LEF Model Adjusted R2:	0.36

# %%
plt.scatter(best_LEF1_UP_V1_UP_W_Feature,best_LEF1_UP_V1_DN_W_Feature,c=Tram_Time_colors)

# %%
gene_regulation_pos_W = Tram_W_dict_PCC035cutoff['positive regulation of gene expression']
best_gene_regulation_pos_W_Feature, best_gene_regulation_pos_W_corr, best_gene_regulation_pos_Windex = fm.GetNegCoefFeature(gene_regulation_pos_W,Tram_Time_values)
print(best_gene_regulation_pos_W_corr)
# Out:
# -0.5332481012638245

# %%
gene_regulation_neg_W = Tram_W_dict_PCC035cutoff['negative regulation of gene expression']
best_gene_regulation_neg_W_Feature, best_gene_regulation_neg_W_corr, best_gene_regulation_neg_Windex = fm.GetPosCoefFeature(gene_regulation_neg_W,Tram_Time_values)
print(best_gene_regulation_neg_W_corr)
# Out:
# 0.44813394203953205

# %%
noRev_reg = LinearRegression().fit(np.array([best_gene_regulation_pos_W_Feature, best_gene_regulation_neg_W_Feature]).transpose(), Tram_Time_values)
noRev_reg_R2 = noRev_reg.score(np.array([best_gene_regulation_pos_W_Feature, best_gene_regulation_neg_W_Feature]).transpose(), Tram_Time_values)
print("Tram Gene Expression Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# Tram Gene Expression Model Adjusted R2:	0.299

# %%
plt.scatter(best_gene_regulation_pos_W_Feature,best_gene_regulation_neg_W_Feature,c=Tram_Time_colors)

# %%
cell_cycle_pos_W = Tram_W_dict_PCC035cutoff['positive regulation of cell cycle']
best_cell_cycle_pos_W_Feature, best_cell_cycle_pos_W_corr, best_cell_cycle_pos_Windex = fm.GetNegCoefFeature(cell_cycle_pos_W,Tram_Time_values)
print(best_cell_cycle_pos_W_corr)
# Out:
# -0.4920573419492713

# %%
response_to_drug_W = Tram_W_dict_PCC035cutoff['response to drug']
best_response_to_drug_W_Feature, best_response_to_drug_W_corr, best_response_to_drug_Wndex = fm.GetPosCoefFeature(response_to_drug_W,Tram_Time_values)
print(best_response_to_drug_W_corr)
# Out:
# 0.5788717536803765

# %%
noRev_reg = LinearRegression().fit(np.array([best_cell_cycle_pos_W_Feature, best_response_to_drug_W_Feature]).transpose(), Tram_Time_values)
noRev_reg_R2 = noRev_reg.score(np.array([best_cell_cycle_pos_W_Feature, best_response_to_drug_W_Feature]).transpose(), Tram_Time_values)
print("Tram Cell Cycle vs. Drug Response Model Adjusted R2:\t" + "{:.3}".format(noRev_reg_R2))
# Out:
# Tram Cell Cycle vs. Drug Response Model Adjusted R2:	0.356

# %%
plt.scatter(best_cell_cycle_pos_W_Feature,best_response_to_drug_W_Feature,c=Tram_Time_colors)
